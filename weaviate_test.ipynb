# %%
import weaviate

client = weaviate.Client(
    url="http://localhost:3000",
)

# %%
schema_list=client.schema.get()

# %%
schema_list
# Out:
# {'classes': [{'class': 'MockExamQuestion',
#    'description': "This property was generated by Weaviate's auto-schema feature on Sun Jun  9 23:20:58 2024",
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['number'],
#      'description': "This property was generated by Weaviate's auto-schema feature on Sun Jun  9 23:20:58 2024",
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'name': 'global_questionID'},
#     {'dataType': ['number'],
#      'description': "This property was generated by Weaviate's auto-schema feature on Sun Jun  9 23:20:58 2024",
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'name': 'year'},
#     {'dataType': ['text'],
#      'description': "This property was generated by Weaviate's auto-schema feature on Sun Jun  9 23:20:58 2024",
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'question',
#      'tokenization': 'word'},
#     {'dataType': ['text[]'],
#      'description': "This property was generated by Weaviate's auto-schema feature on Sun Jun  9 23:20:58 2024",
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'options',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': "This property was generated by Weaviate's auto-schema feature on Sun Jun  9 23:20:58 2024",
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'answer_key',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': "This property was generated by Weaviate's auto-schema feature on Sun Jun  9 23:20:58 2024",
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'topic',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': "This property was generated by Weaviate's auto-schema feature on Sun Jun  9 23:20:58 2024",
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'description',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': "This property was generated by Weaviate's auto-schema feature on Sun Jun  9 23:20:58 2024",
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'question_number',
#      'tokenization': 'word'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'none'},
#   {'class': 'VERBA_Cache_MiniLM',
#    'description': 'Cache of Documentations and their queries',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Query',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'query',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'System message',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'system',
#      'tokenization': 'word'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'none'},
#   {'class': 'VERBA_Cache_OLLAMA',
#    'description': 'Cache of Documentations and their queries',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Query',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'query',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'System message',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'system',
#      'tokenization': 'word'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'none'},
#   {'class': 'VERBA_Cache_text2vec_cohere',
#    'description': 'Cache of Documentations and their queries',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'moduleConfig': {'text2vec-cohere': {'vectorizeClassName': True}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Query',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'query',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'System message',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': True,
#        'vectorizePropertyName': False}},
#      'name': 'system',
#      'tokenization': 'word'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'text2vec-cohere'},
#   {'class': 'VERBA_Cache_text2vec_openai',
#    'description': 'Cache of Documentations and their queries',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'moduleConfig': {'text2vec-openai': {'baseURL': 'https://api.openai.com',
#      'model': 'ada',
#      'vectorizeClassName': True}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Query',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'query',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'System message',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': True,
#        'vectorizePropertyName': False}},
#      'name': 'system',
#      'tokenization': 'word'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'text2vec-openai'},
#   {'class': 'VERBA_Chunk_MiniLM',
#    'description': 'Chunks of Documentations',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Content of the document',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'text',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Document name',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'doc_name',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Document type',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'doc_type',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Document UUID',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'doc_uuid',
#      'tokenization': 'word'},
#     {'dataType': ['number'],
#      'description': 'Document chunk from the whole document',
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'name': 'chunk_id'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'none'},
#   {'class': 'VERBA_Chunk_OLLAMA',
#    'description': 'Chunks of Documentations',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Content of the document',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'text',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Document name',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'doc_name',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Document type',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'doc_type',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Document UUID',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'doc_uuid',
#      'tokenization': 'word'},
#     {'dataType': ['number'],
#      'description': 'Document chunk from the whole document',
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'name': 'chunk_id'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'none'},
#   {'class': 'VERBA_Chunk_text2vec_cohere',
#    'description': 'Chunks of Documentations',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'moduleConfig': {'text2vec-cohere': {'vectorizeClassName': True}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Content of the document',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'text',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Document name',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'doc_name',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Document type',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': True,
#        'vectorizePropertyName': False}},
#      'name': 'doc_type',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Document UUID',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': True,
#        'vectorizePropertyName': False}},
#      'name': 'doc_uuid',
#      'tokenization': 'word'},
#     {'dataType': ['number'],
#      'description': 'Document chunk from the whole document',
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'moduleConfig': {'text2vec-cohere': {'skip': True,
#        'vectorizePropertyName': False}},
#      'name': 'chunk_id'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'text2vec-cohere'},
#   {'class': 'VERBA_Chunk_text2vec_openai',
#    'description': 'Chunks of Documentations',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'moduleConfig': {'text2vec-openai': {'baseURL': 'https://api.openai.com',
#      'model': 'ada',
#      'vectorizeClassName': True}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Content of the document',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'text',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Document name',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'doc_name',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Document type',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': True,
#        'vectorizePropertyName': False}},
#      'name': 'doc_type',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Document UUID',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': True,
#        'vectorizePropertyName': False}},
#      'name': 'doc_uuid',
#      'tokenization': 'word'},
#     {'dataType': ['number'],
#      'description': 'Document chunk from the whole document',
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'moduleConfig': {'text2vec-openai': {'skip': True,
#        'vectorizePropertyName': False}},
#      'name': 'chunk_id'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'text2vec-openai'},
#   {'class': 'VERBA_Config',
#    'description': 'Configuration JSON',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'JSON String Config',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'config',
#      'tokenization': 'word'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'none'},
#   {'class': 'VERBA_Document_MiniLM',
#    'description': 'Documentation',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Content of the document',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'text',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Document name',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'doc_name',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Document type',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'doc_type',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Link to document',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'doc_link',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Timestamp of document',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'timestamp',
#      'tokenization': 'word'},
#     {'dataType': ['number'],
#      'description': 'Number of chunks',
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'name': 'chunk_count'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'none'},
#   {'class': 'VERBA_Document_OLLAMA',
#    'description': 'Documentation',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Content of the document',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'text',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Document name',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'doc_name',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Document type',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'doc_type',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Link to document',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'doc_link',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Timestamp of document',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'timestamp',
#      'tokenization': 'word'},
#     {'dataType': ['number'],
#      'description': 'Number of chunks',
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'name': 'chunk_count'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'none'},
#   {'class': 'VERBA_Document_text2vec_cohere',
#    'description': 'Documentation',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Content of the document',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'text',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Document name',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'doc_name',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Document type',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'doc_type',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Link to document',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'doc_link',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Timestamp of document',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'timestamp',
#      'tokenization': 'word'},
#     {'dataType': ['number'],
#      'description': 'Number of chunks',
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'name': 'chunk_count'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'none'},
#   {'class': 'VERBA_Document_text2vec_openai',
#    'description': 'Documentation',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Content of the document',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'text',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Document name',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'doc_name',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Document type',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'doc_type',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Link to document',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'doc_link',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Timestamp of document',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'timestamp',
#      'tokenization': 'word'},
#     {'dataType': ['number'],
#      'description': 'Number of chunks',
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'name': 'chunk_count'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'none'},
#   {'class': 'VERBA_MockExamQuestion_text2vec_cohere',
#    'description': 'UPSC Mock Exam Questions',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'moduleConfig': {'text2vec-cohere': {'vectorizeClassName': True}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Text of the question',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'questionText',
#      'tokenization': 'word'},
#     {'dataType': ['text[]'],
#      'description': 'Array of answer options',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'options',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'The correct answer',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'correctAnswer',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Explanation for the answer (optional)',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'explanation',
#      'tokenization': 'word'},
#     {'dataType': ['int'],
#      'description': 'Year of the exam question',
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'year'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'text2vec-cohere'},
#   {'class': 'VERBA_MockExamQuestion_text2vec_openai',
#    'description': 'UPSC Mock Exam Questions',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'moduleConfig': {'text2vec-openai': {'baseURL': 'https://api.openai.com',
#      'model': 'ada',
#      'vectorizeClassName': True}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Text of the question',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'questionText',
#      'tokenization': 'word'},
#     {'dataType': ['text[]'],
#      'description': 'Array of answer options',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'options',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'The correct answer',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'correctAnswer',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Explanation for the answer (optional)',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'explanation',
#      'tokenization': 'word'},
#     {'dataType': ['int'],
#      'description': 'Year of the exam question',
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'year'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'text2vec-openai'},
#   {'class': 'VERBA_Suggestion',
#    'description': 'List of possible prompts',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Query',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'name': 'suggestion',
#      'tokenization': 'word'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'none'},
#   {'class': 'VERBA_VERBA_MockExamQuestion_text2vec_cohere_text2vec_openai',
#    'description': 'UPSC Mock Exam Questions',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'moduleConfig': {'text2vec-openai': {'baseURL': 'https://api.openai.com',
#      'model': 'ada',
#      'vectorizeClassName': True}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Text of the question',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'questionText',
#      'tokenization': 'word'},
#     {'dataType': ['text[]'],
#      'description': 'Array of answer options',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'options',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'The correct answer',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'correctAnswer',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Explanation for the answer (optional)',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'explanation',
#      'tokenization': 'word'},
#     {'dataType': ['int'],
#      'description': 'Year of the exam question',
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'year'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'text2vec-openai'},
#   {'class': 'VERBA_VERBA_MockExamQuestion_text2vec_openai_text2vec_cohere',
#    'description': 'UPSC Mock Exam Questions',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'moduleConfig': {'text2vec-cohere': {'vectorizeClassName': True}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Text of the question',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'questionText',
#      'tokenization': 'word'},
#     {'dataType': ['text[]'],
#      'description': 'Array of answer options',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'options',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'The correct answer',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'correctAnswer',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Explanation for the answer (optional)',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'explanation',
#      'tokenization': 'word'},
#     {'dataType': ['int'],
#      'description': 'Year of the exam question',
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'year'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'text2vec-cohere'},
#   {'class': 'VERBA_VERBA_VERBA_MockExamQuestion_text2vec_cohere_text2vec_openai_MiniLM',
#    'description': 'UPSC Mock Exam Questions',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'moduleConfig': {'text2vec-openai': {'baseURL': 'https://api.openai.com',
#      'model': 'ada',
#      'vectorizeClassName': True}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Text of the question',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'questionText',
#      'tokenization': 'word'},
#     {'dataType': ['text[]'],
#      'description': 'Array of answer options',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'options',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'The correct answer',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'correctAnswer',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Explanation for the answer (optional)',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'explanation',
#      'tokenization': 'word'},
#     {'dataType': ['int'],
#      'description': 'Year of the exam question',
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'year'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'text2vec-openai'},
#   {'class': 'VERBA_VERBA_VERBA_MockExamQuestion_text2vec_cohere_text2vec_openai_OLLAMA',
#    'description': 'UPSC Mock Exam Questions',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'moduleConfig': {'text2vec-openai': {'baseURL': 'https://api.openai.com',
#      'model': 'ada',
#      'vectorizeClassName': True}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Text of the question',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'questionText',
#      'tokenization': 'word'},
#     {'dataType': ['text[]'],
#      'description': 'Array of answer options',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'options',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'The correct answer',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'correctAnswer',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Explanation for the answer (optional)',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'explanation',
#      'tokenization': 'word'},
#     {'dataType': ['int'],
#      'description': 'Year of the exam question',
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'year'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'text2vec-openai'},
#   {'class': 'VERBA_VERBA_VERBA_MockExamQuestion_text2vec_openai_text2vec_cohere_MiniLM',
#    'description': 'UPSC Mock Exam Questions',
# ...
#        'vectorizePropertyName': False}},
#      'name': 'questionText',
#      'tokenization': 'word'},
#     {'dataType': ['text[]'],
#      'description': 'Array of answer options',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'options',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'The correct answer',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'correctAnswer',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Explanation for the answer (optional)',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'explanation',
#      'tokenization': 'word'},
#     {'dataType': ['int'],
#      'description': 'Year of the exam question',
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'year'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'text2vec-cohere'},
#   {'class': 'VERBA_VERBA_VERBA_MockExamQuestion_text2vec_openai_text2vec_cohere_OLLAMA',
#    'description': 'UPSC Mock Exam Questions',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'moduleConfig': {'text2vec-cohere': {'vectorizeClassName': True}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Text of the question',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'questionText',
#      'tokenization': 'word'},
#     {'dataType': ['text[]'],
#      'description': 'Array of answer options',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'options',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'The correct answer',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'correctAnswer',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Explanation for the answer (optional)',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'explanation',
#      'tokenization': 'word'},
#     {'dataType': ['int'],
#      'description': 'Year of the exam question',
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'year'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'text2vec-cohere'},
#   {'class': 'VERBA_VERBA_VERBA_VERBA_MockExamQuestion_text2vec_cohere_text2vec_openai_MiniLM_OLLAMA',
#    'description': 'UPSC Mock Exam Questions',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'moduleConfig': {'text2vec-openai': {'baseURL': 'https://api.openai.com',
#      'model': 'ada',
#      'vectorizeClassName': True}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Text of the question',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'questionText',
#      'tokenization': 'word'},
#     {'dataType': ['text[]'],
#      'description': 'Array of answer options',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'options',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'The correct answer',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'correctAnswer',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Explanation for the answer (optional)',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'explanation',
#      'tokenization': 'word'},
#     {'dataType': ['int'],
#      'description': 'Year of the exam question',
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'year'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'text2vec-openai'},
#   {'class': 'VERBA_VERBA_VERBA_VERBA_MockExamQuestion_text2vec_cohere_text2vec_openai_OLLAMA_MiniLM',
#    'description': 'UPSC Mock Exam Questions',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'moduleConfig': {'text2vec-openai': {'baseURL': 'https://api.openai.com',
#      'model': 'ada',
#      'vectorizeClassName': True}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Text of the question',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'questionText',
#      'tokenization': 'word'},
#     {'dataType': ['text[]'],
#      'description': 'Array of answer options',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'options',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'The correct answer',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'correctAnswer',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Explanation for the answer (optional)',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'explanation',
#      'tokenization': 'word'},
#     {'dataType': ['int'],
#      'description': 'Year of the exam question',
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'year'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'text2vec-openai'},
#   {'class': 'VERBA_VERBA_VERBA_VERBA_MockExamQuestion_text2vec_openai_text2vec_cohere_MiniLM_OLLAMA',
#    'description': 'UPSC Mock Exam Questions',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'moduleConfig': {'text2vec-cohere': {'vectorizeClassName': True}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Text of the question',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'questionText',
#      'tokenization': 'word'},
#     {'dataType': ['text[]'],
#      'description': 'Array of answer options',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'options',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'The correct answer',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'correctAnswer',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Explanation for the answer (optional)',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'explanation',
#      'tokenization': 'word'},
#     {'dataType': ['int'],
#      'description': 'Year of the exam question',
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'year'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'text2vec-cohere'},
#   {'class': 'VERBA_VERBA_VERBA_VERBA_MockExamQuestion_text2vec_openai_text2vec_cohere_OLLAMA_MiniLM',
#    'description': 'UPSC Mock Exam Questions',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'moduleConfig': {'text2vec-cohere': {'vectorizeClassName': True}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': 'Text of the question',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'questionText',
#      'tokenization': 'word'},
#     {'dataType': ['text[]'],
#      'description': 'Array of answer options',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'options',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'The correct answer',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'correctAnswer',
#      'tokenization': 'word'},
#     {'dataType': ['text'],
#      'description': 'Explanation for the answer (optional)',
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'explanation',
#      'tokenization': 'word'},
#     {'dataType': ['int'],
#      'description': 'Year of the exam question',
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'moduleConfig': {'text2vec-cohere': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'year'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}},
#     'bq': {'enabled': False}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'text2vec-cohere'}]}

# %%
#'class': 'MockExamQuestion',

# %%
results=client.query.get(
    "MockExamQuestion",
    ["question", "options", "answer_key", "year", "topic", "description", "question_number"],
).with_limit(4).do()

# %%
results
# Out:
# {'data': {'Get': {'MockExamQuestion': [{'answer_key': 'c',
#      'description': 'President can issue Ordinance under Article 123.',
#      'options': ['Article 121', 'Article 122', 'Article 123', 'Article 124'],
#      'question': 'Under which Article of the Indian Constitution did the President give\nhis assent to the ordinance on electoral reforms when it was sent back to\nhim by the Union Cabinet without making any changes (in the year 2002)?',
#      'question_number': '26',
#      'topic': 'Constitution & Polity',
#      'year': 2003},
#     {'answer_key': 'a,c',
#      'description': 'Article 85 of the Indian Constitution empowers the President to summon each house of the Parliament at such time and place as he thinks fit. (Hence, 1st statement is correct) • The Constitution of India does not mention the anything about the number of Parliamentary sessions in a year. (Hence, 2nd statement is incorrect)• There is some ambiguity in the 3rd statement. • If the UPSC interprets it in a narrow and literal sense, then exact number of days for which the Parliament is supposed to meet in a year is not mentioned in the Constitution and hence, 3rd statement is correct.• However, if we interpret the question in a broader manner, then Article 85 of the Indian Constitution mentions that 6 months shall not intervene the 2 sessions of the Parliament. Interpreting this clause, it essentially means that Parliament has to meet at least for 2 days in a year to prevent the violation of Article 85. In such a scenario, 3rd statement is incorrect.',
#      'options': ['1 only', '2 only', '1 and 3 only', '2 and 3 only'],
#      'question': 'Consider the following statements:\n\n1. The president of India can summon a session of Parliament at such place\nas he/she thinks fit.\n2. The Constitution of India provides for three sessions of the Parliament in\na year, but it is not mandatory to conduct all three sessions\n3. There is no minimum number of days that the Parliament is required to\nmeet in a year.\nWhich of the statements given above is/are correct?',
#      'question_number': '123',
#      'topic': 'Government & Administration',
#      'year': 2020},
#     {'answer_key': 'a',
#      'description': 'Statement 1 is correct as under Article 360, any Proclamation of Financial Emergency issued shall cease to operate at the expiration of two months, unless before the expiration of that period it has been approved by the resolutions Passed by both Houses of Parliament. If approved by both Houses, then it operates for 6 months. During the proclamation of financial emergency. President of India can issue directions for the reduction of salaries and allowances of all or any class of persons serving in connection with the affairs of the union including the judges of supreme court and the High courts.',
#      'options': ['1 only', '2 only', 'Both 1 and 2', 'Neither 1 nor 2'],
#      'question': 'Consider the following statements in respect of financial emergency under Article 360 of the Constitution of India: 1. A proclamation of financial emergency issued shall cease to operate at the expiration of two months, unless before the expiration of that period it has been approved by the resolutions of both Houses of Parliament. 2. If any proclamation of financial emergency is in operation, it is competent for the President of India to issue directions for the reduction of salaries and allowances of all or any class of persons serving in connection with the affairs of the Union but excluding the Judges of Supreme Court and the High Courts. Which of the statements given above is/are correct?',
#      'question_number': '55',
#      'topic': 'Government & Administration',
#      'year': 2007},
#     {'answer_key': 'd',
#      'description': 'Badruddin Tyabji was not associated with the Muslim League but he was the first Muslim president of INC in 1887 at Madras.',
#      'options': ['1, 2, 3 and 4', '2 and 4', '1, 3 and 4', '1, 2 and 3'],
#      'question': 'Which of the following pairs are correctly matched? 1. Theodore Beck : Mohammedan Anglo Oriental College, Aligarh. 2. Ilbert Bill: Ripon 3. Pherozeshah Mehta: Indian National Congress 4. Badruddin Tyabji: Muslims League Select the correct answer using the codes given below:',
#      'question_number': '35',
#      'topic': 'Indian National Movement',
#      'year': 1998}]}}}

# %%
client.schema.delete_class('MockExamQuestion')
