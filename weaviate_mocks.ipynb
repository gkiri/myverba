# %%
### Use Env d:/software/miniconda/<>/verba/python.exe

# %%
VOYAGEAI_API_KEY='pa-ZYY-It_A8EjQmjYzGvf5iTUR5Vb1zh4XUFP5iIy--DK'
headers = {
    "X-VoyageAI-Api-Key": VOYAGEAI_API_KEY,
}

# %%
import weaviate
# "http://3.83.67.48:8000/api/health";
# http://3.89.115.184:8080/v1
client = weaviate.Client(
    url="http://3.89.115.184:8080",
    additional_headers=headers  # Example for OpenAI
)
# Out:
# d:\Softwares\miniconda\installation\envs\verba\lib\site-packages\weaviate\warnings.py:133: DeprecationWarning: Dep005: You are using weaviate-client version 4.6.4. The latest version is 4.10.4.
#             Consider upgrading to the latest version. See https://weaviate.io/developers/weaviate/client-libraries/python for details.
#   warnings.warn(

# %%
schema_list=client.schema.get()

# %%
len(schema_list['classes'])
# Out:
# 32

# %% [markdown]
# ### View list of classes

# %%
for name in schema_list['classes']:
    print(name['class'])
# Out:
# MOCKS
# VERBA_Cache_text2vec_cohere
# VERBA_Chunk_text2vec_openai
# VERBA_VERBA_VERBA_MockExamQuestion_text2vec_cohere_text2vec_openai_OLLAMA
# VERBA_Cache_OLLAMA
# VERBA_Document_OLLAMA
# VERBA_Document_text2vec_openai
# VERBA_Syllabus_Chapters
# VERBA_VERBA_VERBA_MockExamQuestion_text2vec_openai_text2vec_cohere_MiniLM
# VERBA_VERBA_VERBA_MockExamQuestion_text2vec_cohere_text2vec_openai_MiniLM
# VERBA_Cache_MiniLM
# VERBA_Chunk_MiniLM
# VERBA_Config
# VERBA_Document_text2vec_palm
# VERBA_MockExamQuestion_text2vec_cohere
# VERBA_VERBA_MockExamQuestion_text2vec_cohere_text2vec_openai
# VERBA_VERBA_MockExamQuestion_text2vec_openai_text2vec_cohere
# VERBA_VERBA_VERBA_VERBA_MockExamQuestion_text2vec_cohere_text2vec_openai_OLLAMA_MiniLM
# VERBA_Chunk_OLLAMA
# VERBA_Syllabus_Subtopics
# PYQS
# VERBA_Document_MiniLM
# VERBA_MockExamQuestion_text2vec_openai
# VERBA_Suggestion
# VERBA_VERBA_VERBA_MockExamQuestion_text2vec_openai_text2vec_cohere_OLLAMA
# VERBA_Cache_text2vec_openai
# VERBA_Chunk_text2vec_cohere
# VERBA_VERBA_VERBA_VERBA_MockExamQuestion_text2vec_cohere_text2vec_openai_MiniLM_OLLAMA
# VERBA_Document_text2vec_cohere
# VERBA_Document_text2vec_voyage
# VERBA_VERBA_VERBA_VERBA_MockExamQuestion_text2vec_openai_text2vec_cohere_MiniLM_OLLAMA
# VERBA_VERBA_VERBA_VERBA_MockExamQuestion_text2vec_openai_text2vec_cohere_OLLAMA_MiniLM

# %% [markdown]
# ### Analyse specific class

# %%
schema_list['classes'][6]
# Out:
# {'class': 'VERBA_Document_text2vec_openai',
#  'description': 'Documentation',
#  'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#   'cleanupIntervalSeconds': 60,
#   'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#  'multiTenancyConfig': {'autoTenantActivation': False,
#   'autoTenantCreation': False,
#   'enabled': False},
#  'properties': [{'dataType': ['text'],
#    'description': 'Content of the document',
#    'indexFilterable': True,
#    'indexRangeFilters': False,
#    'indexSearchable': True,
#    'name': 'text',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'description': 'Document name',
#    'indexFilterable': True,
#    'indexRangeFilters': False,
#    'indexSearchable': True,
#    'name': 'doc_name',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'description': 'Document type',
#    'indexFilterable': True,
#    'indexRangeFilters': False,
#    'indexSearchable': True,
#    'name': 'doc_type',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'description': 'Link to document',
#    'indexFilterable': True,
#    'indexRangeFilters': False,
#    'indexSearchable': True,
#    'name': 'doc_link',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'description': 'Timestamp of document',
#    'indexFilterable': True,
#    'indexRangeFilters': False,
#    'indexSearchable': True,
#    'name': 'timestamp',
#    'tokenization': 'word'},
#   {'dataType': ['number'],
#    'description': 'Number of chunks',
#    'indexFilterable': True,
#    'indexRangeFilters': False,
#    'indexSearchable': False,
#    'name': 'chunk_count'}],
#  'replicationConfig': {'asyncEnabled': False, 'factor': 1},
#  'shardingConfig': {'actualCount': 1,
#   'actualVirtualCount': 128,
#   'desiredCount': 1,
#   'desiredVirtualCount': 128,
#   'function': 'murmur3',
#   'key': '_id',
#   'strategy': 'hash',
#   'virtualPerPhysical': 128},
#  'vectorIndexConfig': {'bq': {'enabled': False},
#   'cleanupIntervalSeconds': 300,
#   'distance': 'cosine',
#   'dynamicEfFactor': 8,
#   'dynamicEfMax': 500,
#   'dynamicEfMin': 100,
#   'ef': -1,
#   'efConstruction': 128,
#   'flatSearchCutoff': 40000,
#   'maxConnections': 64,
#   'pq': {'bitCompression': False,
#    'centroids': 256,
#    'enabled': False,
#    'encoder': {'distribution': 'log-normal', 'type': 'kmeans'},
#    'segments': 0,
#    'trainingLimit': 100000},
#   'skip': False,
#   'sq': {'enabled': False, 'rescoreLimit': 20, 'trainingLimit': 100000},
#   'vectorCacheMaxObjects': 1000000000000},
#  'vectorIndexType': 'hnsw',
#  'vectorizer': 'none'}

# %%
# Schema for Mock exam PYQS

# %% [markdown]
# ### Schema for Mock exam PYQS

# %%
SCHEMA_MOCK_EXAM = {
    "classes": [
        {
            "class": "MOCKS",
            "description": "UPSC Mock Exam Questions",
            "vectorizer": "text2vec-voyageai",
            "moduleConfig": {
                "text2vec-voyageai": {
                    "model": "voyage-3",  # Best model for semantic search
                    "vectorizeClassName": False,
                    "textFields": ["question", "description"]  # Combine these for vectorization
                }
            },
            "properties": [
                {
                    "name": "global_questionID",
                    "dataType": ["text"],
                    "description": "Unique identifier for the question"
                },
                {
                    "name": "year",
                    "dataType": ["text"],
                    "description": "Year of the exam question"
                },
                {
                    "name": "question",
                    "dataType": ["text"],
                    "description": "Text of the question",
                    "moduleConfig": {
                        "text2vec-voyageai": {
                            "skip": False  # Include in vectorization
                        }
                    }
                },
                {
                    "name": "options",
                    "dataType": ["text[]"],
                    "description": "Array of answer options"
                },
                {
                    "name": "answer_key",
                    "dataType": ["text"],
                    "description": "Correct answer key"
                },
                {
                    "name": "topic",
                    "dataType": ["text"],
                    "description": "Question topic"
                },
                {
                    "name": "description",
                    "dataType": ["text"],
                    "description": "Answer explanation",
                    "moduleConfig": {
                        "text2vec-voyageai": {
                            "skip": False  # Include in vectorization
                        }
                    }
                },
                {
                    "name": "question_number",
                    "dataType": ["text"],
                    "description": "Original question number"
                }
            ]
        }
    ]
}

# %%
print("Available modules:", client.get_meta()["modules"])
# Out:
# Available modules: {'generative-openai': {'documentationHref': 'https://platform.openai.com/docs/api-reference/completions', 'name': 'Generative Search - OpenAI'}, 'qna-openai': {'documentationHref': 'https://platform.openai.com/docs/api-reference/completions', 'name': 'OpenAI Question & Answering Module'}, 'text2vec-cohere': {'documentationHref': 'https://docs.cohere.ai/embedding-wiki/', 'name': 'Cohere Module'}, 'text2vec-openai': {'documentationHref': 'https://platform.openai.com/docs/guides/embeddings/what-are-embeddings', 'name': 'OpenAI Module'}, 'text2vec-voyageai': {'documentationHref': 'https://docs.voyageai.com/docs/embeddings', 'name': 'VoyageAI Module'}}

# %%
#client.schema.delete_class("PYQS")
#client.schema.delete_class("MOCKS")

# %%
client.schema.create(SCHEMA_MOCK_EXAM)

# %%
meta_info = client.get_meta()

# %%
meta_info
# Out:
# {'hostname': 'http://[::]:8080',
#  'modules': {'generative-openai': {'documentationHref': 'https://platform.openai.com/docs/api-reference/completions',
#    'name': 'Generative Search - OpenAI'},
#   'qna-openai': {'documentationHref': 'https://platform.openai.com/docs/api-reference/completions',
#    'name': 'OpenAI Question & Answering Module'},
#   'text2vec-cohere': {'documentationHref': 'https://docs.cohere.ai/embedding-wiki/',
#    'name': 'Cohere Module'},
#   'text2vec-openai': {'documentationHref': 'https://platform.openai.com/docs/guides/embeddings/what-are-embeddings',
#    'name': 'OpenAI Module'},
#   'text2vec-voyageai': {'documentationHref': 'https://docs.voyageai.com/docs/embeddings',
#    'name': 'VoyageAI Module'}},
#  'version': '1.26.5'}

# %% [markdown]
# ### Vectorizer Testing

# %%
from weaviate.classes.config import Configure

# %% [markdown]
# ### Prepare questions

# %%
#D:\UPSC-AI\Data\mock prelims\data\qa-4701.json
#file =''
#filename = r"d:\UPSC-AI\Data\mock prelims\data\qa-4701.json"
filename = r"d:\UPSC-AI\Data\mock prelims\data\qa-merged.json"# 4701+4716

# %%
import json

with open(filename, 'r', encoding='utf-8') as file:
    data = json.load(file)

# %%
len(data)
# Out:
# 200

# %%
data[0]
# Out:
# {'year': '',
#  'question': 'Consider the following statements regarding the identities provided by the Constitution:\n1. A constitution provides a collective identity to people when they agree to basic norms.\n2. Constitutional norms provide a political identity but not a moral one.\nWhich of the statements given above is/are correct?',
#  'options': ['(a) 1 only',
#   '(b) 2 only',
#   '(c) Both 1 and 2',
#   '(d) Neither 1 nor 2'],
#  'topic': 'Indian Polity',
#  'description': "Fundamental identity of a people.\n  A constitution expresses the fundamental identity of a people. This means the people as a collective\nentity come into being only through the basic constitution.\n It is by agreeing to a basic set of norms about how one should be governed, and who should be\ngoverned that one forms a collective identity.\n The constitution expresses the fundamental identity of a people, and this collective identity\ncomes into being when individuals agree to a basic set of norms on governance and authority.\nHence statement 1 is correct.\nOne has many sets of identities that exist before a constitution. However, the constitution provides\ntwo identities. They are\n✓ Political Identity: People by agreeing to certain basic norms and principles one constitute one's\nbasic political identity.\n✓ Moral Identity: Constitutional norms are the overarching framework within which one pursues\nindividual aspirations, goals, and freedoms. The Constitution sets authoritative constraints upon\nwhat one may or may not do. It defines the fundamental values that we may not trespass. So\nthe constitution also gives one a moral identity. Hence statement 2 is not correct.",
#  'question_number': '1',
#  'answer_key': 'a',
#  'global_questionID': '1'}

# %%
from pydantic import BaseModel, field_validator ,ValidationError
from typing import Literal,List

# Question model for the Mock Exam
class Question(BaseModel):
    global_questionID: str # Unique identifier for the question - made optional for import 
    year: str                # Year of the exam question
    question: str          # The question text
    options: List[str]     # A list of answer options
    answer_key: str         # The correct answer key (e.g., 'a', 'b', 'c', 'd') 
    topic: str = ""           # Topic of the question (optional)
    description: str = ""      # Explanation for the answer (optional)
    question_number: str = ""   # Question number in the original exam (optional)

# %%
# Validate question structure within the list
for question_data in data:
    try:
        Question(**question_data)  # Attempt to create a Question object
    except ValidationError as e: 
        raise ValueError(f"Invalid question data: {e}")

    break

# %% [markdown]
# #### Upload to weavaite with vectorization

# %%
from wasabi import msg  # type: ignore[import]
with client.batch as batch:
    batch.batch_size = 100  # Set batch size
    for question_data in data:
        question_data['global_questionID'] = question_data['global_questionID'] #str
        #question_data['year'] = int(question_data['year'])
        question = Question(**question_data)
        properties = question.model_dump() 
        client.batch.add_data_object(properties, "MOCKS")
msg.good(f"Successfully uploaded and imported {len(data)} mock exam questions.")
# Out:
# ✔ Successfully uploaded and imported 200 mock exam questions.

# %% [markdown]
# #### verify count of objects uploaded

# %%
# Get count of questions in MOCKS class
result = (
    client.query
    .aggregate("MOCKS")
    .with_meta_count()
    .do()
)

# Print the total count
print(f"Total questions in database: {result['data']['Aggregate']['MOCKS'][0]['meta']['count']}")
# Out:
# Total questions in database: 200

# %%
def get_question_by_id(client, question_id: int):
    result = (
        client.query
        .get("MOCKS", ["question", "options", "answer_key", "year", "global_questionID", "description"])
        .with_where({
            "path": ["global_questionID"],
            "operator": "Equal",
            "valueInt": question_id  # Convert to string
        })
        .do()
    )
    
    # Add error handling and formatting
    if result and 'data' in result and 'Get' in result['data'] and 'MOCKS' in result['data']['Get']:
        questions = result['data']['Get']['MOCKS']
        if questions:
            return questions[0]  # Return first matching question
    return None

# Example usage
question_id = 15  # Replace with the ID you want to retrieve
result = get_question_by_id(client, question_id)
result

# %% [markdown]
# ### Sample Experiements PYQS print

# %% [markdown]
# #### Aggregate total count

# %%
#Aggregate all chapters count
result_agg = (
    client.query
    .aggregate("MOCKS")
    .with_fields("meta {count}")
    .do()
)
result_agg
# Out:
# {'data': {'Aggregate': {'MOCKS': [{'meta': {'count': 200}}]}}}

# %% [markdown]
# #### Random questions from class

# %%
obj=client.data_object.get(class_name="MOCKS",limit=2)['objects']
obj
# Out:
# [{'class': 'MOCKS',
#   'creationTimeUnix': 1738547567388,
#   'id': '0185738d-0d76-49f4-9c30-f9c448733b21',
#   'lastUpdateTimeUnix': 1738547567388,
#   'properties': {'answer_key': 'b',
#    'description': 'The Finance Commission consists of a chairman and four other members to be appointed by the\npresident. They hold office for such a period as specified by the president in his order. They are eligible\nfor reappointment.\nThe Constitution authorises the Parliament to determine the qualifications of members of the\ncommission and the manner in which they should be selected. Hence option (b) is the correct\nanswer.\nAccordingly, the Parliament has specified the qualifications of the chairman and members of the\ncommission1. The chairman should be a person having experience in public affairs and the four other\nmembers should be selected from amongst the following:\nΟ A judge of the high court or one qualified to be appointed as one.\nΟ A person who has specialized knowledge of finance and accounts of the government.\nΟ A person who has wide experience in financial matters and in administration.\nΟ A person who has special knowledge of economics.',
#    'global_questionID': '54',
#    'options': ['(a) Union Cabinet',
#     '(b) Parliament',
#     '(c) Supreme Court of India',
#     '(d) President'],
#    'question': 'Who among the following determines the qualification and the manner of selection of members of the Finance Commission?',
#    'question_number': '54',
#    'topic': 'Indian Polity',
#    'year': ''},
#   'vectorWeights': None},
#  {'class': 'MOCKS',
#   'creationTimeUnix': 1738547567388,
#   'id': '01f1adfb-ddf6-4d71-a2e3-8e68f21accf2',
#   'lastUpdateTimeUnix': 1738547567388,
#   'properties': {'answer_key': 'B',
#    'description': 'Right against Exploitation includes Article 23 and 24 of the Constitution.\nArticle 23 prohibits traffic in human beings, begar (forced labour) and other similar forms of forced\nlabour.',
#    'global_questionID': '31',
#    'options': ['(a) Only one', '(b) Only two', '(c) All three', '(d) None'],
#    'question': 'How many of the following are envisaged as the Right against Exploitation in the Constitution of India?\n1. Protection against arrest and detention\n2. Prohibition of employment of children in factories.\n3. Prohibition of traffic in human beings and forced labour\nSelect the correct answer using the code given below.',
#    'question_number': '31',
#    'topic': 'Indian Polity',
#    'year': ''},
#   'vectorWeights': None}]

# %% [markdown]
# #### global_questionID based question retrirve

# %%
result = (
    client.query
    .get("MOCKS", ["question", "options"])
    .with_where({
        "path": ["global_questionID"],
        "operator": "Equal",
        "valueText": "24"  # Use ID from actual data
    })
    .do()
)

result
# Out:
# {'data': {'Get': {'MOCKS': [{'options': ['(a) Only one',
#       '(b) Only two',
#       '(c) All three',
#       '(d) None'],
#      'question': 'Consider the following statements with respect to the members of the Central Vigilance Commission (CVC):\n1. The members of the CVC are appointed by the President by warrant under his hand and seal.\n2. The members of the CVC hold office for a term of six years or until they attain the age of seventy, whichever is earlier.\n3. The president can also remove the Central Vigilance Commissioner on the grounds of proven misbehavior or incapacity.\nHow many of the statements given above are correct?'}]}}}

# %%
### Question number

# %%
result = (
    client.query
    .get("MOCKS", ["question", "options"])
    .with_where({
        "path": ["question_number"],
        "operator": "Equal",
        "valueText": "55"  # Use ID from actual data
    })
    .do()
)

result
# Out:
# {'data': {'Get': {'MOCKS': [{'options': ['(a) Sarkaria Commission',
#       '(b) Swaran Singh committee',
#       '(c) L M Singhvi committee',
#       '(d) Punchhi Commission'],
#      'question': 'The Fundamental Duties were added to Indian constitution on the recommendation of which of the following commissions/ committees?'},
#     {'options': ['(a) Tropical Monsoon Climate',
#       '(b) The Cool Temperate Eastern Margin climate',
#       '(c) The Arctic or Polar Climate',
#       '(d) The Warm Temperate Eastern Margin Climate'],
#      'question': 'Consider the following passage :\nIt is an intermediate type of climate between the British and the Siberian type of climate. It has features of both the maritime and the continental climates. It has cold, dry winters and warm, wet summers. Winter temperatures may be well blow freezing-point and snow falls to quite a depth. Summers are as warm as the tropics. Though rain falls throughout the year, there is a distinct summer maximum from the easterly winds from the oceans. In the southern hemisphere, this climatic type is absent.\nWhich of the climate is being described in the passage given above?'}]}}}

# %% [markdown]
# #### retrieve few glbal question ids

# %%
# Check first 5 objects
sample_objs = client.query.get("MOCKS", ["question"]).with_limit(5).do()
print("Sample objects:", sample_objs)
# Out:
# Sample objects: {'data': {'Get': {'MOCKS': [{'question': 'Who among the following determines the qualification and the manner of selection of members of the Finance Commission?'}, {'question': 'How many of the following are envisaged as the Right against Exploitation in the Constitution of India?\n1. Protection against arrest and detention\n2. Prohibition of employment of children in factories.\n3. Prohibition of traffic in human beings and forced labour\nSelect the correct answer using the code given below.'}, {'question': 'Which of the following practices are considered appropriate for soil conservation?\n1. Integrated Pest Management\n2. Monocropping\n3. Terrace farming\n4. Strip cropping\n5. Land Tilling\nSelect the correct answer using the code given below.'}, {'question': 'Consider following statements regarding the recognition of World Craft Cities:\n1. The World Craft City designation is awarded by UNESCO.\n2. Ahmedabad has been recently recognized as a World Craft City.\nWhich of the statements given above is/are correct?'}, {'question': "Which of the following suitably describes North-east India as per Koppen's classification?"}]}}}

# %% [markdown]
# #### Vector retrieve

# %%
# Get vector for a specific question by ID
result = (
    client.query
    .get("MOCKS", ["question"])
    .with_additional("vector")  # Add vector to response
    .with_where({
        "path": ["global_questionID"],
        "operator": "Equal",
        "valueText": "24"
    })
    .do()
)

if result['data']['Get']['MOCKS']:
    print("Vector:", result['data']['Get']['MOCKS'][0]['_additional']['vector'])
# Out:
# Vector: [-0.00845331, 0.028419137, 0.003198792, -0.058765862, 0.014280018, 0.050606623, -0.002408221, -0.002272163, 0.01982575, -0.026422964, -0.037800245, -0.00578786, -0.011617364, -0.00352429, -0.01026248, -0.04997974, 0.026541801, 0.007865354, 0.061323058, 0.026444137, -0.03594428, -0.005515241, 0.024700647, -0.003788166, 0.039327692, -0.019775443, 0.011008704, -0.04097101, -0.039423697, 0.008476029, -0.020886114, -0.004893732, -0.023102267, 0.020352198, 0.023217244, 0.019238094, -0.044458833, -0.027362017, 0.052103598, -0.026048586, -0.014341338, -0.015999187, 0.071697176, -0.00898784, -0.037223693, 0.048415624, -0.041536503, -0.028892871, 0.002804555, 0.03554729, 0.008815584, -0.068395525, -0.006785477, -0.060064256, -0.026194805, 0.05602165, -0.011688526, 0.006486831, -0.009775371, -0.00506833, 0.03357308, -0.013675698, -0.025263354, -0.03281614, -0.026579313, -0.003923937, 0.012874226, 0.002002661, -0.025891984, 0.052296586, -0.022116618, -0.001138472, -0.028124932, -0.013254219, -0.029576795, -0.079557456, 0.003765063, -0.033762574, -0.033765186, 0.023546237, -0.024347506, 0.0481832, -0.009830397, 0.020777147, -0.029233323, 0.02316439, 0.01580628, 0.026425498, 0.002543352, -0.04056255, -0.03116047, -0.008282356, -0.027714832, -0.000987094, 0.008726047, -0.011447474, -0.016999751, -0.02903769, 0.047472052, 0.051329218, 0.009628898, -0.01267331, -0.003973274, -0.045675535, 0.031402286, -0.02752741, 0.022026636, -0.021248382, 0.01046208, -0.016356705, -0.014886272, 0.03749885, 0.050813843, 0.038422223, -0.024973178, -0.01691461, 0.013955778, -0.034613594, 0.00329222, -0.041272808, -0.006079136, -0.032749057, 0.005449471, 0.021465024, 0.009375528, -0.021286624, 0.036787108, -0.025219455, -0.03294028, -0.014362083, 0.053455643, 0.002478321, -0.002634218, 0.03977682, -0.007502047, 0.063781634, -0.023470243, 0.010198483, -0.04525139, -0.022272661, -0.054153346, -0.001973125, 0.046724238, -0.08115227, -0.05756027, -0.016743213, -0.016021706, -0.03621496, 0.015611596, -0.006807693, -0.013622645, 0.036839478, -0.003831931, 0.010914214, -0.028542724, -0.02530232, -0.062205084, 0.014893178, -0.030751703, 0.030453125, 0.019820914, -0.058049843, 0.047717128, 0.0468527, -0.014222655, 0.029385338, 0.032609556, 0.03968082, -0.03604338, -0.025407758, 0.041556716, 0.008454747, 0.024516178, -0.031481523, 0.024963522, 0.04514158, 0.023046363, -0.020041902, 0.015448381, 0.00962312, 0.006159166, 0.014534827, 0.024831582, -0.025855368, -0.00594311, -0.009701616, -0.03095275, 0.030094463, -0.022558512, 0.001882275, 0.067534655, -0.035763413, 0.033252835, 0.015503767, -0.007664179, 0.04612781, -0.01270762, -0.001573337, 0.011190881, 0.063983925, 0.07494829, 0.048452735, 0.019365354, -0.04167331, -0.052244924, -0.055100847, -0.007530694, 0.015477313, 0.06978211, -0.002439981, 0.016844297, -0.015286316, 0.03502742, -0.01901231, 0.012487169, 0.02279791, 0.0915545, -0.04706767, 0.042124458, -0.006637606, -0.013058288, -0.04561164, 0.011910392, -0.008361598, 0.010430788, 0.006517874, 0.062311973, 0.040088322, -0.000851866, -0.0681032, -0.03693619, 0.005791157, -0.0340825, -0.015683599, 0.047568172, -0.003133458, 0.0131304, -0.0153065, -0.027611444, 0.002936574, 0.009400264, 0.025004972, -0.008972339, 0.029229963, -0.042336773, 0.039100654, -0.004559004, -0.008877529, -0.03265481, 0.030533396, -0.037670285, -0.017381981, -0.05885563, -0.033080384, 0.010775121, 0.04312614, 0.008424324, -0.013521959, -0.021398054, 0.003653849, 0.005405081, -0.020794937, -0.005583964, -0.036228184, 0.011962741, 0.004291355, -0.033003796, -0.044985715, 0.005546558, 0.022129778, 0.016708486, -0.034049522, -0.016853327, 0.030638568, 0.018257458, 0.005750079, 0.017915502, 0.031620726, -0.008234283, 0.047894195, 0.02139415, 0.011825827, 0.014331249, -0.029896218, -0.011350892, -0.017695839, -0.012214193, -0.007158012, -0.017633839, -0.0212608, 0.04727257, -0.00043605, 0.018738506, 0.04927624, 0.010933041, -0.033316307, -0.017067675, -0.024235832, 0.053524267, -0.04046585, - ...

# %%
#vector dim
len(result['data']['Get']['MOCKS'][0]['_additional']['vector'])
# Out:
# 1024

# %% [markdown]
# #### Semantic search

# %%
subtopic="""
Hello! I'm your AI mentor for UPSC preparation, and I'm excited to guide you through this crucial subtopic on Ecology and Environment. This section focuses on the historical interplay between human civilization and the natural world, a perspective often overlooked but vital for understanding the environmental challenges we face today. It's not just about memorizing facts; it's about understanding the process of human-environment interaction.

Let's break down the provided text into manageable chunks.

1. Ecology and Environment: An Introduction

The text begins by establishing the context: the explosive growth of human populations and industrialization has dramatically altered our relationship with the environment. "Ecology and environment" is presented as the study of this interaction. Ecology itself, a relatively young science, examines the interactions between living organisms – plants, animals, and humans. The text emphasizes the fundamental shift in this interaction from ancient times (humans living off the land) to the industrial age (humans actively preserving and manipulating the natural world).

Key takeaway: The core issue is understanding the dynamic relationship between humans and their environment, a relationship that has undergone profound changes throughout history.
2. Environment and Human Advance: A Historical Perspective

The text then expands on the concept of "environment", defining it as both natural (soil, air, water) and man-made (food, shelter, infrastructure). This shows the profound effect human actions have had on both. Crucially, it cautions against "environmental determinism," the idea that the environment entirely dictates human actions. Instead, it highlights the active role humans play in shaping their surroundings (e.g., deforestation for agriculture). The example of migrations due to climatic changes in Central Asia (around 2000 BC) illustrates the impact of environmental factors on human settlements, while also stressing the human agency in responding to these challenges.

Key takeaway: Human actions significantly shape the environment, and vice-versa. Environmental changes have influenced human migration and settlement patterns. This is not a one-way street.
3. Surroundings and Settlements: The Role of Resources and Technology

This section delves into the impact of technology on human settlement and resource use. The development and use of iron tools (around 500 BC) facilitated large-scale agriculture in the Gangetic plains, leading to significant deforestation and the expansion of settlements. The example of the Gangetic plains demonstrates how human progress often came at the cost of the natural environment, showing the long-term consequences of human intervention. The changing course of the Sarasvati River and its impact on the Harappan civilization serves as another example of how environmental changes could drastically impact settlements. The location of cities like Pataliputra, situated strategically at river junctions, highlights the interplay between human choices and environmental factors in urban development.

Key takeaway: Technological advancements enabled humans to further exploit natural resources, often resulting in significant environmental modification. The choice of settlement location was, and is, profoundly influenced by environmental factors.
4. The Rain and Human Effort: Climate's Impact

The crucial role of rainfall in shaping human societies is emphasized. The Harappan civilization's success and decline are connected to rainfall patterns. The impact of monsoons on daily life (Gautama Buddha suspending his teachings during the rainy season) highlights the integration of human activities with environmental rhythms.

Key takeaway: Climate and rainfall are pivotal factors influencing agricultural practices, settlement patterns, and even social customs.
5. Ancient Attitudes Towards the Environment: A Religious and Cultural Lens

This section explores the cultural and religious perspectives on the environment in ancient India. The reverence for rivers (Ganga), trees (Pipal, Neem), and animals (cows, elephants) illustrates the intertwining of religious beliefs and environmental conservation. While there wasn’t organized environmental protection, certain practices implicitly showed respect for the natural world. The Buddhist emphasis on non-violence and the protection of cows demonstrates early ethical considerations regarding the environment.

Key takeaway: While modern environmentalism is a relatively recent development, ancient cultures had their own perspectives and practices, some of which showed implicit environmental respect.
6. Conclusion: The text concludes by reaffirming the ongoing interaction between human actions and the environment. Human progress has always involved a degree of exploitation of the natural world. Understanding this interaction is crucial for a complete understanding of history.

Key takeaway: Human history and environmental history are inextricably linked; one cannot be understood without the other.
This structured overview should help you understand the key concepts. We can now go back and delve into any specific areas that require further clarification. Do you have any questions or points you'd like to discuss in more detail?




"""

# %%
subtopic2="""

Namaste! I'm Dr. Anya, your AI mentor for UPSC preparation. We'll be exploring the significance of ancient Indian history today, focusing on how it shapes our understanding of India's unity in diversity and its relevance to contemporary challenges. This is a crucial topic for the UPSC exam, so let's delve in systematically.

First, let's situate this subtopic within the broader context. Understanding ancient Indian history isn't just about memorizing dates and names; it's about grasping the foundational elements that shaped modern India. This section specifically focuses on how the past explains India's unique blend of unity amidst incredible diversity, and how understanding this past helps us address present-day issues.

Part 1: The Significance of Ancient Indian History

The provided text highlights several key aspects. The study of ancient India reveals the origins of our earliest cultures, showcasing how people developed agriculture, utilized resources, and built societies. It also underlines the importance of ancient scripts and languages as the roots of what we use today. Think of it like tracing a river to its source – we understand the river better when we understand its origins.

Part 2: Unity in Diversity

This is a crucial concept for UPSC. Ancient India wasn't a monolithic entity. Many groups – pre-Aryans, Indo-Aryans, Greeks, Scythians, Hunas, Turks, and others – interacted and contributed to the cultural melting pot. The text uses the example of linguistic influence: Munda, Dravidian, and other non-Sanskritic terms appear in Vedic texts, demonstrating the intermingling of cultures even in early Vedic times. Similarly, Sanskrit and Pali terms are found in Sangam literature, demonstrating a cultural exchange between the Gangetic plains and the south. This highlights that despite diverse origins, these cultures fused, creating a unique Indian identity. It wasn't simply a case of one replacing another; there was a complex process of mutual influence.

Do you understand how the examples of linguistic exchange illustrate the concept of "unity in diversity"? Let's pause here before we move on.

(Pause for student response and clarification)

Okay, let’s proceed. The text further emphasizes the geographical and cultural integration of the subcontinent. While many states existed, the idea of Aryavarta (northern and central India) and Bharatavarsha (land of the Bharatas) emerged, reflecting a growing sense of shared identity. The attempts by emperors like Ashoka and Samudragupta to unify the land further showcase this drive towards territorial and political unity. Even the term "Hindu," originating from the Iranian interpretation of "Sindhu" (Indus), reveals how foreigners recognized India as a single geographical entity. This continued with the spread of Prakrit and later Sanskrit as lingua francas.

Even in the face of many smaller states after the Gupta period, the use of Sanskrit in official documents shows a continued attempt at linguistic unity. The popularity of the Ramayana and Mahabharata, in various languages, illustrates the unifying power of shared cultural values.

Part 3: The Relevance of the Past to the Present

This section is crucial for UPSC as it links historical understanding to contemporary issues. The text cautions against romanticizing the past. While ancient India saw remarkable advancements, it also suffered from significant social injustices like the caste system and the subordination of women. Understanding this is key to avoiding the pitfalls of blindly wanting to "restore" aspects of the past without acknowledging its flaws.

The text concludes by highlighting how past prejudices and social structures like the caste system continue to impact India today. Studying ancient history helps us understand the roots of these obstacles and aids in overcoming them. It’s not about rejecting our heritage, but about learning from both the successes and failures of the past to build a better future.

(Pause for student questions and discussion)

Finally, the chronology provided helps place these cultural and linguistic exchanges within a historical timeframe. Remembering these broad time periods will aid in your understanding of the evolution of Indian society and culture.

This concludes our exploration of this subtopic. Do you have any questions or points you'd like to revisit? Remember, understanding the past is crucial to navigating the present and preparing for the future – and excelling in the UPSC exam!


"""

# %%
def semantic_search(query: str, limit: int = 5):
    """Perform semantic search on MOCKS questions"""
    result = (
        client.query
        .get("MOCKS", ["question", "options", "answer_key", "description"])
        .with_near_text({"concepts": [query]})  # VoyageAI vector search
        .with_limit(limit)
        .with_additional(["distance"])
        .do()
    )

    if not result['data']['Get']['MOCKS']:
        return []

    return [
        {
            "question": item["question"],
            "answer": item["answer_key"],
            "confidence": 1 - item["_additional"]["distance"], # Convert distance to similarity score
            "explanation": item["description"]
        }
        for item in result['data']['Get']['MOCKS']
    ]

# Example usage
#results = semantic_search("government systems in different countries")
results = semantic_search(subtopic)

print(f"Found {len(results)} relevant questions:")
for result in results:
    print(f"Q: {result['question']} (Confidence: {result['confidence']:.2%})")
    print(f"A: {result['answer']}\nExplanation: {result['explanation']}\n")
# Out:
# Found 5 relevant questions:
# Q: Consider the following natural phenomena:
# 1. Plate tectonics
# 2. Volcanic activity
# 3. River erosion
# 4. Earthquake
# Which of the above geographical phenomena play an important role in the formation of "duns" in the Himalayas? (Confidence: 39.00%)
# A: c
# Explanation: • Duns are longitudinal valleys located between the lesser Himalayas and Shivalik.
# • The Shivalik range was uplifted as a result of the collision between the Indian Plate and The Eurasian
# Plate. As the Shivalik range rises, the land between the Shivalik and the lesser Himalayas becomes
# compressed. This compression creates longitudinal fault and due to tectonic activity depression or
# valley begins to form between these two ranges. These valleys are the beginning of the dunes.
# • Several rivers such as Yamuna, Ganga and their tributaries flow down from the higher Himalayan
# range and enter the dun valley. These rivers actively erode the valley floor and walls, carrying away
# sediments and widening the valley over time.
# • In addition to eroding the valley, the rivers deposit alluvium (fine sediments like silt, clay, and sand) in
# the duns, creating fertile plains. The deposition process is intensified during the monsoon season when
# rivers swell and carry large amounts of sediment downstream.
# • Over time, with the combined effect of the tectonic activity and river erosion, these valleys become
# broader and flatter, forming the characteristic flat-bottomed duns. The valleys become ideal locations for
# human habitation due to their fertile soil and relatively mild topography compared to the rugged
# Himalayan terrain surrounding them. Hence option (c) is the correct answer.
#
# Q: Consider the following pairs in the context of rainfall distribution in India:
#
# Average Rainfall                          Region
# 1. Heavy Rainfall :         Brahmaputra
# exceeds 400 cm              valley
# 2. Moderate                      :          Northern
# Rainfall between              Ganga plain
# 100-200
# 3. Low Rainfall          :           Western Uttar
# between 50-100 cm                Pradesh
#
# How many pairs given above are correctly matched? (Confidence: 37.88%)
# A: b
# Explanation: Distribution of Rainfall
# The average annual rainfall in India is about 125 cm, but it has great spatial variations. i.e.
# • Areas of High Rainfall: The highest rainfall occurs along the west coast, on the Western Ghats, as well as in the sub-Himalayan areas is the northeast and the hills of Meghalaya. Here the rainfall exceeds 200 cm. In some parts of Khasi and Jaintia hills, the rainfall exceeds 1,000 cm. In the Brahmaputra valley and the adjoining hills, the rainfall is less than 200 cm. Hence, pair 1 is not correctly matched.
# • Areas of Medium Rainfall: Rainfall between 100-200 cm is received in the southern parts of Gujarat, east Tamil Nadu, northeastern Peninsula covering Odisha, Jharkhand, Bihar, eastern Madhya Pradesh, northern Ganga plain along the sub-Himalayas and the Cachar Valley and Manipur. Hence, pair 2 is correctly matched.
# • Areas of Low Rainfall: Western Uttar Pradesh, Delhi, Haryana, Punjab, Jammu and Kashmir, eastern Rajasthan, Gujarat and Deccan Plateau receive rainfall between 50-100 cm. Hence, pair 3 is correctly matched.
# • Areas of Inadequate Rainfall: Parts of the Peninsula, especially in Andhra Pradesh, Karnataka and Maharashtra, Ladakh and most of western Rajasthan receive rainfall below 50 cm. Snowfall is restricted to the Himalayan region.
#
# Q: Consider the following statements with respect to Chotanagpur Plateau:
# 1. It is one of the oldest landmasses on the Earth containing Precambrian rocks.
# 2. In the past, it was part of the Deccan plateau.
# 3. Rajmahal hills forms the southernmost boundary of it.
# Which of the statements given above are correct? (Confidence: 35.61%)
# A: a
# Explanation: • The Chotanagpur region is a plateau in eastern India, covering the states of Jharkhand, Orissa, West
# Bengal, Bihar, and Chhattisgarh.
# • The Chottanagpur plateau is one of the oldest landmasses on the earth. It is composed of Precambrian
# rocks that are more than 540 million years old. Hence statement 1 is correct.
# • Geohistorically, it was part of the Deccan Plate, which broke free from the southern continent during
# the Cretaceous period to embark upon a 50-million-year journey that was violently interrupted by the
# northern Eurasian continent. Hence statement 2 is correct.
# • To the north of Chottanagpur lie the Rajmahal Hills, which are very important on account of their
# fossiliferous deposits (containing knowledge about the richness of floristic diversity, phylogeny, and plant
# evolution). Hence statement 3 is not correct.
# • The plateau in its entirety lies between the basins of the Ganges and the Son Rivers to the north, and the
# Mahanadi River to the south.
# • Ecologically, the Chotanagpur region lies between the moist deciduous forests of the Eastern Ghats and
# the Satpura Range and the lower reaches of the Gangetic Plains in eastern India.
#
# Q: These forests occur in the areas that receive low rainfall. These consist of a variety of grasses and shrubs. In these forests, plants remain leafless for most part of the year and give an expression of scrub vegetation. Important species found are babool, ber, and wild date palm, khair, neem, khejri, palas, etc. Which of the following types of forests is being described in the above-given passage? (Confidence: 34.97%)
# A: c
# Explanation: Tropical thorn forests occur in the areas which receive rainfall less than 50 cm. These consist of a
# variety of grasses and shrubs. It includes semi-arid areas of south west Punjab, Haryana,
# Rajasthan, Gujarat, Madhya Pradesh and Uttar Pradesh. In these forests, plants remain leafless for
# most part of the year and give an expression of scrub vegetation. Important species found are
# babool, ber, and wild date palm, khair, neem, khejri, palas, etc. Tussocky grass grows upto a height of
# 2 m as the under growth. Hence option (c) is the correct answer.
# The Moist deciduous forests are more pronounced in the regions which record rainfall between 100-200
# cm. These forests are found in the northeastern states along the foothills of Himalayas, eastern slopes of
# the Western Ghats and Odisha. Teak, sal, shisham, hurra, mahua, amla, semul, kusum, and sandalwood
# etc. are the main species of these forests.
# Dry deciduous forest covers vast areas of the country, where rainfall ranges between 70 -100 cm. On the
# wetter margins, it has a transition to the moist deciduous, while on the drier margins to thorn forests.
# These forests are found in rainier areas of the Peninsula and the plains of Uttar Pradesh and Bihar. In the
# higher rainfall regions of the Peninsular plateau and the northern Indian plain, these forests have a
# parkland landscape with open stretches in which teak and other trees interspersed with patches of grass are
# common. As the dry season begins, the trees shed their leaves completely and the forest appears like a
# vast grassland with naked trees all around. Tendu, palas, amaltas, bel, khair, axlewood, etc. are the
# common trees of these forests. In the western and southern part of Rajasthan, vegetation cover is very
# scanty due to low rainfall and overgrazing.
# Montane Forests In mountainous areas, the decrease in temperature with increasing altitude leads to a
# corresponding change in natural vegetation. Mountain forests can be classified into two types, the
# northern mountain forests and the southern mountain forests.
#
# Q: Which of the following correctly identifies the era, period, and epoch in which we are currently living? (Confidence: 34.72%)
# A: b
# Explanation: Understanding Geological Time: Eras, Periods, and Epochs
# Geological time is divided into units that help scientists understand Earth's history. These divisions include eras, periods, and epochs, which represent specific times during Earth's development based on major geological, climatic, and biological events.
# Currently, we are living in the Cenozoic Era, within the Quaternary Period and the Holocene Epoch. Hence option (b) is the correct answer.

# %%
subtopic3="""Namaste! I'm your AI mentor for UPSC preparation, and I'm thrilled to guide you through this fascinating subtopic: "The Beginnings of European Settlements." This section is crucial because it lays the groundwork for understanding the later colonial expansion of European powers in Asia, a topic frequently tested in the UPSC exam.

Let's break down the provided text into manageable chunks. First, we see that European involvement with India isn't a sudden event; it has deep roots going back to ancient Greece. The Middle Ages saw established trade routes between Europe and Asia, primarily controlled by Arab merchants in the East and Italian merchants in the Mediterranean. These routes, though profitable due to the high demand for spices in Europe, faced numerous challenges—high taxes, piracy, and natural disasters. This highlights the importance of spices in the European diet and the considerable profits generated by this trade.

Pause for understanding: Do you have any questions so far about the early trade routes and their challenges?

Now, let's move on to the next section. The Ottoman conquest of Constantinople in 1453 significantly altered the existing trade landscape. It disrupted the established routes and placed them under Turkish control. Furthermore, the Italian city-states like Venice and Genoa monopolized the trade, blocking Western European nations (like Spain and Portugal) from participating. This created a strong incentive for these Western powers to seek alternative routes.

Pause for understanding: Can you summarize why Western European nations sought new sea routes to the East?

The text then describes the pivotal role of Portugal and Spain. Their voyages of discovery, fueled by the desire for spices, gold, and a less perilous route, mark a turning point. Columbus's accidental discovery of America and Vasco da Gama's successful sea route around Africa to India are presented as monumental events, transforming world trade and global power dynamics.

Pause for understanding: What were the major motivations behind the Portuguese and Spanish voyages of discovery, and what were their key achievements?

The text also highlights the importance of the transatlantic slave trade in accumulating capital for European powers, particularly England and France. It details the "triangular trade" – manufactured goods from Europe to Africa, slaves from Africa to the Americas, and colonial produce from the Americas back to Europe – and its immense profitability, fueling European economic growth and contributing to the Industrial Revolution. The inhumane conditions and massive loss of life in Africa are also acknowledged. Finally, the text briefly covers the Portuguese colonial ambitions in India, their use of force alongside trade, and their eventual decline due to various factors.

Pause for understanding: Can you explain the concept of the "triangular trade" and its significance? How did it contribute to European power? What were some of the factors that led to the decline of the Portuguese Empire in the East?

The concluding section emphasizes that this period saw a shift of economic and political power westward towards the Atlantic powers, ultimately resulting in British dominance in India and Dutch control over Indonesia. Understanding this shift in power is crucial for grasping the larger context of colonialism and its lasting impact.

Key takeaways for UPSC:

Early trade routes: Understand the different routes, the key players (Arab and Italian merchants), and the challenges faced.
Motivations for exploration: The demand for spices, gold, and the desire to bypass existing monopolies are key.
Impact of discoveries: The discovery of America and the sea route to India fundamentally altered world trade and power dynamics.
Transatlantic slave trade: Its economic importance, its human cost, and its contribution to the Industrial Revolution are vital aspects.
Rise and fall of colonial powers: Understand the reasons for the success of Portugal, Spain, England, and the Netherlands, and the reasons for their relative decline.
Remember to connect these concepts with other relevant areas in your UPSC preparation, such as the economic history of India, the impact of colonialism, and the social and political consequences of globalization. This holistic approach will significantly enhance your understanding and exam performance. Do you have any questions or need further clarification on any of these points?"""

# %%
def semantic_search(query: str, limit: int = 10):
    """Perform semantic search on MOCKS questions"""
    result = (
        client.query
        .get("MOCKS", ["question", "options", "answer_key", "description"])
        .with_near_text({"concepts": [query]})
        .with_limit(limit)
        .with_additional(["distance"])
        .do()
    )

    if not result['data']['Get']['MOCKS']:
        return []

    return [
        {
            "question": item["question"],
            "answer": item["answer_key"],
            "confidence": 1 - item["_additional"]["distance"],  # Convert to similarity score
            "distance": item["_additional"]["distance"],  # Raw distance value
            "explanation": item["description"]
        }
        for item in result['data']['Get']['MOCKS']
    ]

# Example usage
results = semantic_search(subtopic3)
print(f"Found {len(results)} relevant questions:")
for idx, result in enumerate(results, 1):
    print(f"\nQuestion {idx}:")
    print(f"Score: {result['distance']:.4f} (Distance)")
    print(f"Confidence: {result['confidence']:.2%}")
    print(f"Q: {result['question']}")
    print(f"Explanation: {result['explanation']}")
# Out:
# Found 10 relevant questions:
#
# Question 1:
# Score: 0.6675 (Distance)
# Confidence: 33.25%
# Q: According to the Preamble of the Constitution, as adopted by the Constituent Assembly, how many of the following adjectives were used to define the Indian Republic?
#
# 1. Socialist
# 2. Sovereign
# 3. Secular
# 4. Democratic
#
# Select the correct answer using the code given below.
# Explanation: The Preamble of the Constitution defines the Indian Republic as Sovereign, Socialist, Secular and Democratic. Of these, Sovereign and Democratic were part of the Preamble adopted by the Constituent Assembly. Hence option (b) is the correct answer.
#
# • Socialist and Secular were added to the Preamble by the 42nd Constitutional Amendment Act of 1976. Also, the word 'integrity' was added by the same act.
#
# Question 2:
# Score: 0.6737 (Distance)
# Confidence: 32.63%
# Q: Consider the following statements regarding the Pitts India Act of 1784:
#
# 1. It allowed the Court of Directors of East India Company to manage the political affairs in India.
# 2. The Company's territories in India were for the first time called the 'British possessions in India'.
#
# Which of the statements given above is/are correct?
# Explanation: Pitt's India Act of 1784
#
# In a bid to rectify the defects of the Regulating Act of 1773, the British Parliament passed the
#
# Amending Act of 1781, also known as the Act of Settlement. The next important act was the Pitt's
#
# India Act of 1784.
#
# Features of the Act
#
# It distinguished between the commercial and political functions of the Company.
# It allowed the Court of Directors to manage the commercial affairs but created a new body
#
# called the Board of Control to manage the political affairs. Thus, it established a system of double
#
# government. Hence statement 1 is not correct.
# It empowered the Board of Control to supervise and direct all operations of the civil and military
#
# government or revenues of the British possessions in India.
#
# Thus, the act was significant for two reasons:
#
# 1. The Company's territories in India were for the first time called the 'British possessions in
#
# India'. Hence statement 2 is correct.
#
# 2. The British Government was given supreme control over the Company's affairs and its
#
# administration in India.
#
# Question 3:
# Score: 0.6756 (Distance)
# Confidence: 32.44%
# Q: In the context of economy, what does the term Dutch disease refer to?
# Explanation: • Recently, an observation paper by Economic Advisory Council to the PM (PM-EAC) highlighted the prevalence of Dutch disease in India.
# • Key Observations of the Paper
#   o Regional disparities: While western states have consistently performed well, southern states have performed well post-1991 economic liberalization (5 southern states account for 30% of GDP in 2023-24).
#   o Maritime states: They have clearly outperformed the other states, with the exception of West Bengal.
#   o West Bengal's share of GDP has fallen in 2023-24 (5.6%) in comparison to 1960-61 (10.5%).
#   o Diverging growth trajectories of Punjab and Haryana: However, post-1990s Punjab's contribution to GDP declined whereas Haryana's contribution has grown robustly. The paper questions this as a form of Dutch disease.
# • Dutch Disease in economics refers to a phenomenon wherein a country witnesses uneven growth across sectors due to the discovery of natural resources, especially large oil reserves. Hence option (a) is the correct answer.
#   o According to the concept, when a country discovers natural resources and starts exporting them to the rest of the world, it causes the exchange rate of the currency to appreciate significantly and this, in turn, discourages the exports from other sectors while encouraging the import of cheaper alternatives.
# • How to combat Dutch Disease?
#   o Role of Fiscal Policy: According to the researchers, the role of fiscal policy is important to control the boom following the discovery of natural resources. Rising income due to the export of natural resources should be adjusted with cautious spending on public welfare.
#   o Promote public spending policies: Public spending such as concentrating on imports of tradeables rather than non-tradables would help slow the impact of the Dutch disease. Private spending in order to improve the productivity of private firms would also help reduce the impact.
#   o Role of Monetary Policy: With the discovery of natural resources, the country sees a huge inflow of money, especially foreign currency. The export of natural resources tends to affect the equilibrium in the money and exchange rate markets. The Dutch disease can be prevented if the central bank raises the banking system reserve's requirement, which decreases domestic credit.
#
# Question 4:
# Score: 0.6824 (Distance)
# Confidence: 31.76%
# Q: An Indian citizen may lose his/her citizenship when he/she:
# 1. Acquires the citizenship of any other foreign state during war.
# 2. Unlawfully trades or communicates with the enemy during a war.
# 3. Has been imprisoned in any country for two years after becoming a naturalized citizen within five years.
# Select the correct answer using the code given below.
# Explanation: The Citizenship Act (1955) prescribes three ways of losing citizenship whether acquired under the Act or
#  சுவர்prior to it under the Constitution, viz, renunciation, termination and deprivation:
# By Renunciation: Any citizen of India of full age and capacity can make a declaration renouncing his
# Indian citizenship. Upon the registration of that declaration, that person ceases to be a citizen of India.
# However, if such a declaration is made during a war in which India is engaged, its registration shall be
# withheld by the Central Government. Further, when a person renounces his Indian citizenship, every
# minor child of that person also loses Indian citizenship. However, when such a child attains the age of
# eighteen, he may resume Indian citizenship.
# By Termination: When an Indian citizen voluntarily (consciously, knowingly and without duress,
# undue influence or compulsion) acquires the citizenship of another country, his Indian citizenship
# automatically terminates. This provision, however, does not apply during a war in which India is
# engaged.
# By Deprivation: It is a compulsory termination of Indian citizenship by the Central government, if:
# the citizen has obtained the citizenship by fraud:
# the citizen has shown disloyalty to the Constitution of India:
# the citizen has unlawfully traded or communicated with the enemy during a war;
# the citizen has, within five years after registration or naturalisation, been imprisoned in any
# country for two years; and
# the citizen has been ordinarily resident out of India for seven years Continuously.
#
# Question 5:
# Score: 0.6869 (Distance)
# Confidence: 31.31%
# Q: Consider the following pairs:
# Constitutional Provision Adopted From
# 1. Fundamental Rights : France
# 2. Directive Principles of : Ireland
# State Policy
# 3. Residual Powers with : Canada
# Centre
# 4. Parliamentary Form of : Britain
# Government
# How many of the above pairs are correctly matched?
# Explanation: Government of India Act of 1935:
# Ο Federal Scheme, Office of Governor, Judiciary; Public Service Commissions; Emergency Provisions;
# Administrative Details
# British Constitution:
# Ο Parliamentary Government; Rule of Law; Legislative Procedure; Single Citizenship; Cabinet
# System; Prerogative Writs; Parliamentary Privileges; Bicameralism. Hence pair 4 is correctly
# matched.
# US Constitution:
# Ο Fundamental Rights; Independence of Judiciary; Judicial Review; Impeachment of the President;
# Removal of Supreme Court and High Court Judges; Post of Vice-President. Hence pair 1 is not
# correctly matched.
# Irish Constitution:
# Ο Directive Principles of State Policy; Nomination of Members to Rajya Sabha; Method of Election of
# President. Hence pair 2 is correctly matched.
# Canadian Constitution:
# Ο Federation with a Strong Centre; Vesting of Residuary Powers in the Centre; Appointment of State
# Governors by the Centre; Advisory Jurisdiction of the Supreme Court. Hence pair 3 is correctly
# matched.
# Australian Constitution:
# Ο Concurrent List; Freedom of Trade, Commerce, and Intercourse; Joint Sitting of the Two Houses of
# Parliament
# Weimar Constitution of Germany:
# Ο Suspension of Fundamental Rights during Emergency
# Soviet Constitution (now Russia):
# Ο Fundamental Duties; Ideal of Justice (Social, Economic, and Political) in the Preamble
# French Constitution:
# Ο Republic and the Ideals of Liberty, Equality, and Fraternity in the Preamble
# South African Constitution:
# Ο Procedure for Amendment of the Constitution; Election of Members of Rajya Sabha
# Japanese Constitution:
# Ο Procedure Established by Law
#
# Question 6:
# Score: 0.6934 (Distance)
# Confidence: 30.66%
# Q: Consider the following statements regarding the Charter Act of 1833:
# 1. It deprived the legislative powers of the Governors of Bombay and Madras.
# 2. It ended both the commercial and administrative activities of the East India Company.
# 3. It introduced, for the first time, local representation in the Indian (Central) Legislative Council.
# How many of the above statements are correct?
# Explanation: Charter Act of 1833: This Act was the final step towards centralization in British India.
# 0 Features of the Act.
# It made the Governor-General of Bengal as the Governor-General of India and vested in him all
# civil and military powers. Thus, the act created, for the first time, a Government of India having
# authority over the entire territorial area possessed by the British in India. Lord William Bentick
# was the first governor-general of India.
# It deprived the governors of Bombay and Madras of their legislative powers. The Governor-
# General of India was given exclusive legislative powers for the entire British India. The laws
# made under the previous acts were called Regulations while laws made under this act were called
# Acts. Hence statement 1 is correct.
# It ended the activities of the Fast India Company as a commercial body, which became a
# purely administrative body. It provided that the company's territories in India were held by it
# "in trust for Tlis Majesty. TTis heirs and successors'. Hence statement 2 is not correct.
# The Charter Act of 1833 attempted to introduce a system of open competition for the selection of
# civil servants and stated that the Indians should not be debarred from holding any place, office or
# employment under the Company. However, this provision was negated after opposition from the
# Court of Directors.
# The Charter Act of 1853 introduced, for the first time, local representation in the Indian (Central)
# Legislative Council. Of the six new legislative members of the governor-general's council, four members
# were appointed by the local (provincial) governments of Madras, Bombay, Bengal, and Agra. Hence
# statement 3 is not correct.
#
# Question 7:
# Score: 0.7009 (Distance)
# Confidence: 29.91%
# Q: In the context of the Indian Polity, the Union Public Service Commission (UPSC) is consulted on which of the following matters?
# 1. While making reservations in favor of a backward class of citizens
# 2. Selection for the chairmanship of tribunals
# 3. All matters relating to methods of recruitment to civil services
# Select the correct answer using the code given below.
# Explanation: The Union Public Service Commission (UPSC) is the central recruiting agency in India. Articles 315 to
# 323 in Part XIV of the Constitution contain elaborate provisions regarding the composition,
# appointment, and removal of members along with the independence, powers, and functions of the UPSC.
# It is consulted on the following matters related to personnel management:
# Ο All matters relating to methods of recruitment to civil services and for civil posts.
# Ο The principles to be followed in making appointments to c services and posts and in making
# promotions and transfers from one service to another.
# Ο The suitability of candidates for appointments to civil services and posts; for promotions and transfers
# from one service to another; and appointments by transfer or deputation.
# Ο All disciplinary matters affecting a person serving under the Government of India in a civil capacity
# including memorials and petitions relating to such matters.
# Ο Matters related to grant of extension of service and employment of certain retired civil servants.
# The following matters are kept outside the functional jurisdiction of the UPSC. In other words, the
# UPSC is not consulted on the following matters:
# Ο While making reservations of appointments or posts in favor of any backward class of citizens.
# Ο While taking into consideration the claims of scheduled castes and scheduled tribes in making
# appointments to services and posts.
# Ο With regard to the selections for chairmanship or membership of commissions or tribunals, posts
# of the highest diplomatic nature, and bulk of group C and group D services.
# Ο With regard to the selection for temporary or officiating appointment to a post if the person appointed
# is not likely to hold the post for more than a year.
# Hence option (a) is the correct answer.
#
# Question 8:
# Score: 0.7021 (Distance)
# Confidence: 29.79%
# Q: It separated, for the first time, the legislative and executive functions of the Governor-General's council. In other words, it established a separate Governor-General's legislative council which came to be known as the Indian (Central) Legislative Council. This legislative wing of the council functioned as a mini-parliament, adopting the same procedures as the British Parliament.
# Which of the following Acts has been described by the passage given above?
# Explanation: Charter Act of 1853:
# This was the last of the series of Charter Acts passed by the British Parliament between 1793 and
# 1853. It was a significant constitutional landmark.
# Features of the Act:
# Separation of Legislative and Executive Functions:
# It separated, for the first time, the legislative and executive functions of the Governor-
# General's council.
# It provided for the addition of six new members called legislative councilors to the
# council. In other words, it established a separate Governor-General's legislative council which
# came to be known as the Indian (Central) Legislative Council. This legislative wing of the council
# functioned as a mini-parliament, adopting the same procedures as the British Parliament. Thus,
# legislation, for the first time, was treated as a special function of the government, requiring special
# machinery and special processes. Hence option (b) is the correct answer.
# Introduction of local representation in the Indian (Central) Legislative Council. Four of the
# six new legislative members appointed by local (provincial) governments of Madras,
# Bombay, Bengal, and Agra.
# Open Competition System for Civil Servants:
# Covenanted civil service opened to Indians.
# Introduction of open competition for the selection and recruitment of civil servants.
# Macaulay Committee was appointed in 1854.
# Extension of Company's Rule:
# The Company was allowed to retain possession of Indian territories on trust for the British Crown.
# No specified period, indicating termination of the Company's rule at Parliament's discretion.
#
# Question 9:
# Score: 0.7066 (Distance)
# Confidence: 29.34%
# Q: Consider the following countries:
# 1. Jordan
# 2. Morocco
# 3. Tunisia
# 4. Algeria
# Which of the countries given above share a border with the Mediterranean sea?
# Explanation: The following countries share their borders with the Mediterranean Sea: Spain, France, Monaco, Italy,
# Malta, Slovenia, Croatia, Bosnia and Herzegovina, Montenegro, Albania, Greece, Turkey, Cyprus,
# Syria, Lebanon, Israel, Egypt, Libya, Tunisia, Algeria and Morocco.
#
# Question 10:
# Score: 0.7072 (Distance)
# Confidence: 29.28%
# Q: Which of the following statements is not correct regarding the Indian Independence Act of 1947?
# (a) It abolished the office of the secretary of state of India and transferred its functions to the Governor general of India.
# (b) It empowered the Constituent Assembly to do ordinary legislations till the new constitution was drafted and enforced.
# (c) It abolished the office of viceroy and provided a governor-general, who was to be appointed by the British King.
# (d) It granted freedom to the Indian princely states either to join the Dominion of India or Dominion of Pakistan or to remain independent.
# Explanation: Main Features of the Indian Independence Act (1947):
# Ended British rule and declared India independent on August 15, 1947.
# Partitioned India into two independent dominions: India and Pakistan.
# Abolished the office of Viceroy and established Governors-General for each dominion who was
# to be appointed by the British King on the advice of respective Cabinets.
# Empowered Constituent Assemblies of both dominions to frame their own constitutions.
# Granted temporary legislative power to Constituent Assemblies till new constitutions were
# made.
# Ended British responsibility for the Indian and Pakistani governments.
# Abolished office of Secretary of State for India and transferred functions to Commonwealth
# Affairs. Hence option (a) is the correct answer.
# Lapse of British paramountcy over princely states and tribal areas from August 15, 1947.
# Freedom for princely states to join India, Pakistan, or remain independent.
# Temporary use of the Government of India Act 1935 for governance, with modification powers for
# dominions.
# Removed British Monarch's veto and bill reservation powers, but granted them to the Governor-
# General.
# Made Governor-General and provincial governors constitutional heads acting on ministerial advice.
# Removed the "Emperor of India" title from the British monarch.
# Stopped civil service appointments and reservations by the Secretary of State for India.
# Guaranteed existing benefits to pre-independence civil servants.

# %% [markdown]
# #### BM25 search

# %%
def bm25_search(query: str, limit: int = 10):
    """Perform BM25 search on MOCKS questions"""
    result = (
        client.query
        .get("MOCKS", ["question", "options", "answer_key", "description"])
        .with_bm25(
            query=query,
            properties=["question", "description"]  # Search these text fields
        )
        .with_limit(limit)
        .with_additional(["score"])  # BM25 relevance score
        .do()
    )

    if not result['data']['Get']['MOCKS']:
        return []

    return [
        {
            "question": item["question"],
            "answer": item["answer_key"],
            "score": item["_additional"]["score"],
            "explanation": item["description"]
        }
        for item in result['data']['Get']['MOCKS']
    ]

# Example usage
results = bm25_search(subtopic3)
print(f"Found {len(results)} relevant questions:")
for idx, result in enumerate(results, 1):
    print(f"\nQuestion {idx}:")
    print(f"BM25 Score: {float(result['score']):.4f}")  # Convert string to float first
    print(f"Q: {result['question']}")
    print(f"A: {result['answer']}\nExplanation: {result['explanation']}")
# Out:
# Found 10 relevant questions:
#
# Question 1:
# BM25 Score: 61.1033
# Q: In the context of economy, what does the term Dutch disease refer to?
# A: a
# Explanation: • Recently, an observation paper by Economic Advisory Council to the PM (PM-EAC) highlighted the prevalence of Dutch disease in India.
# • Key Observations of the Paper
#   o Regional disparities: While western states have consistently performed well, southern states have performed well post-1991 economic liberalization (5 southern states account for 30% of GDP in 2023-24).
#   o Maritime states: They have clearly outperformed the other states, with the exception of West Bengal.
#   o West Bengal's share of GDP has fallen in 2023-24 (5.6%) in comparison to 1960-61 (10.5%).
#   o Diverging growth trajectories of Punjab and Haryana: However, post-1990s Punjab's contribution to GDP declined whereas Haryana's contribution has grown robustly. The paper questions this as a form of Dutch disease.
# • Dutch Disease in economics refers to a phenomenon wherein a country witnesses uneven growth across sectors due to the discovery of natural resources, especially large oil reserves. Hence option (a) is the correct answer.
#   o According to the concept, when a country discovers natural resources and starts exporting them to the rest of the world, it causes the exchange rate of the currency to appreciate significantly and this, in turn, discourages the exports from other sectors while encouraging the import of cheaper alternatives.
# • How to combat Dutch Disease?
#   o Role of Fiscal Policy: According to the researchers, the role of fiscal policy is important to control the boom following the discovery of natural resources. Rising income due to the export of natural resources should be adjusted with cautious spending on public welfare.
#   o Promote public spending policies: Public spending such as concentrating on imports of tradeables rather than non-tradables would help slow the impact of the Dutch disease. Private spending in order to improve the productivity of private firms would also help reduce the impact.
#   o Role of Monetary Policy: With the discovery of natural resources, the country sees a huge inflow of money, especially foreign currency. The export of natural resources tends to affect the equilibrium in the money and exchange rate markets. The Dutch disease can be prevented if the central bank raises the banking system reserve's requirement, which decreases domestic credit.
#
# Question 2:
# BM25 Score: 54.7829
# Q: Which among the following countries are landlocked?
# 1. Uzbekistan
# 2. Iran
# 3. Armenia
# 4. Afghanistan
# 5. Azerbaijan
# Select the correct answer using the code given below.
# A: a
# Explanation: A Landlocked country is an independent sovereign state that does not have direct access to an ocean, such
# as the Atlantic, or to a sea that is not landlocked, such as the Mediterranean. Countries such as
# Kazakhstan, in Central Asia, that only have access to a landlocked sea such as the Caspian are considered
# landlocked.
# There are currently 44 landlocked countries. The largest by area is Kazakhstan, in Central Asia, while the
# smallest is the Vatican, in Europe.
# Two countries—Liechtenstein and Uzbekistan-are double-landlocked, making them the only ones
# to be exclusively surrounded by other landlocked countries.
# Afghanistan is a landlocked country between the central Asian countries, Iran and the Indian subcontinent.
# It has to depend on other countries to have decent trade. The Chabahar port built by India and Iran is
# supposed to improve the landlocked country's trade by bypassing Pakistan.
# Iran opens up to the Persian Gulf and the Gulf of Oman connected to the Indian Ocean. Hence, it is
# not a landlocked country. But Armenia and Azerbaijan, the two countries recently engaged in
# conflict are landlocked countries around the Caspian Sea. While Armenia is surrounded by Turkey,
# Georgia, Azerbaijan and Iran, Azerbaijan has the Caspian sea to its east and is surrounded by Armenia,
# Iran, Georgia and Russia. Hence, option (a) is the correct answer.
#
# Question 3:
# BM25 Score: 49.2700
# Q: In the context of trade winds, consider the following statements:
#
# 1. Trade Winds blow from the subtropical high-pressure belts toward the equatorial low-pressure zone.
# 2. Trade Winds blow from the southeast direction in the Northern Hemisphere.
# 3. Trade Winds are stronger over land compared to the oceans.
#
# Which of the statements given above is/are correct?
# A: a
# Explanation: • Trade winds can be defined as the wind that flows towards the equator from the north-east in the Northern Hemisphere or from the south-east in the Southern Hemisphere. These are also known as tropical easterlies and are known for their consistency in force and direction. Trade wind persistent blows westward and toward the Equator from the subtropical high-pressure belts toward the intertropical convergence zone (ITCZ). Hence statement 1 is correct and statement 2 is not correct.
# • These are the winds which blow in the same direction throughout the year, especially over the oceanic regions. During the ancient times these winds helped traders to sail their ships in seas for business purposes for quite long distances. That has given the name "trade wind" to these steady winds.
# • On account of Coriolis force or Ferrel's law, they are deflected from their path (towards right in northern hemisphere and towards left in southern hemisphere).
# • It is stronger and more consistent over the oceans than over land and often produces partly cloudy sky conditions, characterized by shallow cumulus clouds, or clear skies that make trade-wind islands popular tourist resorts. Its average speed is about 5 to 6 metres per second (11 to 13 miles per hour) but can increase to speeds of 13 metres per second (30 miles per hour) or more. Hence statement 3 is not correct.
# • As the wind blows to about five degrees north and south of the equator, both air and ocean currents come to a halt in a band of hot, dry air. This 10-degree belt around Earth's midsection is called the Inter- Tropical Convergence Zone, more commonly known as the doldrums.
#
# Question 4:
# BM25 Score: 48.6405
# Q: Consider the following pairs:
# Passes
# States
# 1. Bom Di La
# : Arunachal Pradesh
# 2. Jelep La
# : Sikkim
# 3. Mana Pass
# : Himachal Pradesh
# 4. Shipki La
# : Uttarakhand
# How many of the pairs given above are correctly matched?
# A: b
# Explanation: • A pass is a gap or break in a mountain range or ridge that allows for passage through the area. Passes are
# formed when glaciers or streams erode the land between higher areas of terrain.
# • Bom Di La is located in Arunachal Pradesh it is situated near the India-China border and is known for its
# scenic views and strategic importance. Other important passes in Arunachal Pradesh are the Dihang pass,
# Yong Yap Pass, Diphar Pass, etc. Hence pair 1 is correctly matched.
# • Jalep La is located in Sikkim. It serves as a pass connecting Sikkim with Tibet, China. It is situated at an
# altitude of about 4200 meters and is an important trade route. Nathu la is another important pass of
# Sikkim. Hence pair 2 is correctly matched.
# • Mana Pass is not located in Himachal Pradesh, it is located in Uttarakhand. Mana Pass was an ancient
# trade route between Uttarakhand and Tibet. The Portuguese Jesuits Antonio de Andrade and Manuel
# Marques became the first known Europeans to enter Tibet across Mana Pass in 1624. Other important
# passes of Uttrakhand are Lipu Lekh, Niti Pass, Muling La, etc. Hence pair 3 is not correctly matched.
# • Shipki La connects India with Tibet and is located in the Kinnaur district of Himachal Pradesh. The Sutlej
# River enters India from Tibet near this pass. Other important passes of Himachal Pradesh are Baralacha
# La, Rohtang Pass, etc. Hence pair 4 is not correctly matched.
#
# Question 5:
# BM25 Score: 44.4036
# Q: Consider the following statements regarding the similarity between Mars and Earth:
# 1. Both have strong magnetic fields that protect them from solar radiation.
# 2. Both have day lengths that are nearly the same.
# 3. Both have a similar axial tilt, which leads to seasons.
# Which of the statements given above are correct?
# A: b
# Explanation: Mars and Earth: A Comparative Analysis
# Mars and Earth, while different in many ways, share some important physical and environmental characteristics. Understanding these similarities is key to determining the potential for Mars to support life or human exploration in the future. The major aspects to compare include the magnetic field, day length, and axial tilt, as these determine planetary protection, surface conditions, and seasonal variations, respectively.
# Magnetic Field and Solar Radiation Protection
# A magnetic field serves as a crucial protective shield for a planet, deflecting harmful solar wind and radiation. On Earth, the magnetic field is generated by the movement of molten iron in the planet's outer core. This strong magnetic field protects Earth from solar radiation, enabling life to thrive on its surface.
# Mars, however, does not have a global magnetic field. Scientific research indicates that Mars once had a strong magnetic field, but it disappeared billions of years ago as its core cooled and became mostly solid. Without a magnetic field, Mars is exposed to high levels of solar radiation, which has stripped away much of its atmosphere over time. The lack of a magnetic field leaves the surface unprotected from solar wind and cosmic radiation. Hence Statement 1 is not correct.
# Day Length on Mars and Earth
# The rotation period of a planet—how long it takes to complete one full rotation on its axis— determines the length of its day. Earth's rotation period is about 24 hours.
# Interestingly, Mars has a very similar day length, with a period of about 24.6 hours. This similarity means that the daily cycles on Mars closely resemble those on Earth, with day and night cycles that are nearly the same in duration.
# This similarity is significant for potential human missions to Mars, as the adjustment to a Martian day would be relatively easy compared to other planets in the solar system. Hence Statement 2 is correct.
# Axial Tilt and Seasonal Changes
# The axial tilt of a planet is the angle at which it tilts on its axis relative to its orbit around the Sun. This tilt determines the seasons experienced by the planet. Earth's axial tilt is about 23.5 degrees, which gives rise to the distinct seasonal changes we experience throughout the year.
# Mars has a very similar axial tilt of about 25 degrees, which also results in seasonal changes. While the atmosphere on Mars is much thinner and its surface much colder, the axial tilt means that Mars, like Earth, experiences seasonal variations in temperature and sunlight distribution. However, due to Mars' longer orbit around the Sun, its seasons last nearly twice as long as those on Earth. Hence Statement 3 is correct.
# Other Similarities Between Mars and Earth
# Presence of Polar Ice Caps: Both Mars and Earth have polar ice caps.
# Surface Features: Mars and Earth share some similar geological features, such as Mountains, Canyons, Deserts e.t.c
# Atmospheric Composition (in Terms of Gases): While Earth's atmosphere is rich in nitrogen and oxygen, both planets share the presence of carbon dioxide in their atmospheres. On Mars, carbon dioxide makes up over 95% of the atmosphere, while on Earth, it is present in much smaller quantities (about 0.04%).
# Key Differences Between Mars and Earth
# Atmosphere and Air Pressure: Mars has a thin atmosphere, composed mostly of CO2, with less than 1% of Earth's air pressure and almost no oxygen. This results in little protection from solar radiation and poor heat retention, contributing to Mars' cold temperatures. In contrast, Earth has a dense atmosphere with 21% oxygen, supporting life and maintaining a stable climate.
# Temperature: Mars is much colder than Earth. The average temperature on Mars is about -60°C (-80°F), whereas Earth's average temperature is around 15°C (59°F).
# Gravity: Mars' gravity is about 38% of Earth's gravity
#
# Question 6:
# BM25 Score: 43.9563
# Q: Consider the following statements:
# 1. The ocean waters at the equatorial belt records high salinity levels due to higher insolation.
# 2. Formation of Sea Ice in oceans decreases salinity levels.
# Which of the statements given above is/are correct?
# A: d
# Explanation: Understanding why the sea is salty begins with knowing how water cycles among the ocean's physical
# states: liquid, vapor, and ice.
#
#     As a liquid, water dissolves rocks and sediments and reacts with emissions from volcanoes and
#     hydrothermal vents. This creates a complex solution of mineral salts in our ocean basins.
#     Conversely, in other states such as vapor and ice, water and salt are incompatible i.e water
#     vapor and ice are essentially salt free. In other words, when ocean water turns into ice, the salt is
#     left behind. This leads to increase in salinity of oceans as existing volume of water decreases and salt
#     content increases. Evaporation of ocean water and formation of sea ice both increase the salinity
#     of the ocean. Hence statement 2 is not correct.
#     By tracking ocean surface salinity we can directly monitor variations in the water cycle: land runoff,
#     sea ice freezing and melting, and evaporation and precipitation over the oceans.
#
# The salinity patterns of the surface waters are influenced largely by wind, by precipitation and
# evaporation patterns.
#
#     The waters within the belt of calm and variable winds near the Equator have lower salinities than
#     those in the trade-wind belts.
#     In the equatorial belt, relatively large amounts of rain fall and little evaporation occurs, both
#     because of low wind speeds and because of the generally cloudy skies; salinity in the equatorial belt
#     runs as low as 34 parts per thousand. Hence statement 1 is not correct.
#
# Question 7:
# BM25 Score: 38.8255
# Q: Consider the following statements regarding the Pitts India Act of 1784:
#
# 1. It allowed the Court of Directors of East India Company to manage the political affairs in India.
# 2. The Company's territories in India were for the first time called the 'British possessions in India'.
#
# Which of the statements given above is/are correct?
# A: b
# Explanation: Pitt's India Act of 1784
#
# In a bid to rectify the defects of the Regulating Act of 1773, the British Parliament passed the
#
# Amending Act of 1781, also known as the Act of Settlement. The next important act was the Pitt's
#
# India Act of 1784.
#
# Features of the Act
#
# It distinguished between the commercial and political functions of the Company.
# It allowed the Court of Directors to manage the commercial affairs but created a new body
#
# called the Board of Control to manage the political affairs. Thus, it established a system of double
#
# government. Hence statement 1 is not correct.
# It empowered the Board of Control to supervise and direct all operations of the civil and military
#
# government or revenues of the British possessions in India.
#
# Thus, the act was significant for two reasons:
#
# 1. The Company's territories in India were for the first time called the 'British possessions in
#
# India'. Hence statement 2 is correct.
#
# 2. The British Government was given supreme control over the Company's affairs and its
#
# administration in India.
#
# Question 8:
# BM25 Score: 38.4553
# Q: Consider the following benefits:
# 1. More accountable form of government
# 2. Improved quality of decision-making
# 3. Resolve conflicts in a better way than others
# How many of the above can be considered as benefits of democracy?
# A: c
# Explanation: Democracy:
# Ο Democracy, a seemingly simple term, encompasses a complex set of ideas and practices. At its core,
# democracy signifies a form of government where power resides with the people. This can take
# diverse forms, including direct democracies where citizens directly participate in decision-making,
# and representative democracies where people elect representatives to make decisions on their
# behalf.
# key features of democracy:
# Ο Popular sovereignty: People hold supreme power and elect their representatives.
# Ο Equality: All citizens, regardless of background, have equal rights and opportunities to participate in
# the political process.
# Ο Freedom: Individuals have fundamental freedoms like speech, assembly, and association, enabling
# them to express their views and hold the government accountable.
# Ο Rule of law: The government operates within a framework of laws that apply equally to everyone,
# including those in power.
# Ο Separation of powers: Different branches of government (executive, legislative, and judiciary) hold
# separate powers, preventing concentration of power and protecting individual rights.
# Benefits of democracy:
# Ο Accountability: Elected leaders are answerable to the people, promoting transparency and
# responsiveness. Hence 1 is correct.
# Ο Improved decision-making: Diverse perspectives and open discussions lead to more informed and
# inclusive decisions. Hence 2 is correct.
# Ο Peaceful conflict resolution: Democratic mechanisms and respect for the rule of law create avenues
# for peaceful resolution of disagreements. Hence 3 is correct.
# Ο Protects individual rights: Fundamental freedoms guarantee personal autonomy and safeguard
# citizens from undue government interference.
# Ο Promotes development: Democratic societies, with informed citizens and accountable governments,
# tend to have better economic and social outcomes.
# Challenges of Democracy:
# Ο Despite its merits, democracy faces challenges:
#
# Question 9:
# BM25 Score: 37.9622
# Q: Consider the following pairs:
# Constitutional Provision Adopted From
# 1. Fundamental Rights : France
# 2. Directive Principles of : Ireland
# State Policy
# 3. Residual Powers with : Canada
# Centre
# 4. Parliamentary Form of : Britain
# Government
# How many of the above pairs are correctly matched?
# A: c
# Explanation: Government of India Act of 1935:
# Ο Federal Scheme, Office of Governor, Judiciary; Public Service Commissions; Emergency Provisions;
# Administrative Details
# British Constitution:
# Ο Parliamentary Government; Rule of Law; Legislative Procedure; Single Citizenship; Cabinet
# System; Prerogative Writs; Parliamentary Privileges; Bicameralism. Hence pair 4 is correctly
# matched.
# US Constitution:
# Ο Fundamental Rights; Independence of Judiciary; Judicial Review; Impeachment of the President;
# Removal of Supreme Court and High Court Judges; Post of Vice-President. Hence pair 1 is not
# correctly matched.
# Irish Constitution:
# Ο Directive Principles of State Policy; Nomination of Members to Rajya Sabha; Method of Election of
# President. Hence pair 2 is correctly matched.
# Canadian Constitution:
# Ο Federation with a Strong Centre; Vesting of Residuary Powers in the Centre; Appointment of State
# Governors by the Centre; Advisory Jurisdiction of the Supreme Court. Hence pair 3 is correctly
# matched.
# Australian Constitution:
# Ο Concurrent List; Freedom of Trade, Commerce, and Intercourse; Joint Sitting of the Two Houses of
# Parliament
# Weimar Constitution of Germany:
# Ο Suspension of Fundamental Rights during Emergency
# Soviet Constitution (now Russia):
# Ο Fundamental Duties; Ideal of Justice (Social, Economic, and Political) in the Preamble
# French Constitution:
# Ο Republic and the Ideals of Liberty, Equality, and Fraternity in the Preamble
# South African Constitution:
# Ο Procedure for Amendment of the Constitution; Election of Members of Rajya Sabha
# Japanese Constitution:
# Ο Procedure Established by Law
#
# Question 10:
# BM25 Score: 37.7029
# Q: Which of the following statement best describes “Totalisation Agreement” which was recently seen in the news?
# (a) It is an agreement through which two countries provide greater market access to each other through various measures like lower or zero tariff.
# (b) It is an agreement between two countries that eliminates dual social security deductions between two countries.
# (c) It is an agreement between two countries to prevent Base Erosion And Profit Shifting.
# (d) It ensures elimination of non-tarrif barrier like sanitary and phytosanitary (SPS) measures.
# A: b
# Explanation: Recently the 14th Ministerial meeting of the India-US trade policy forum was held in New Delhi.
# India reiterated its longstanding demand for a totalisation agreement that will provide social security to
# Indian professionals in the US. A social security pact may help Indian companies in the US, especially
# in the ICT sector, save up to $4 billion every year.
# A totalisation agreement or social security agreement will eliminate dual social security deductions
# in India and the US.
# The implementation of the Totalisation agreement between India and USA would alleviate employers
# from the burden of making dual social security contributions for the same group of employees
# posted in other countries. Additionally, employees would be spared from making redundant social
# security contributions in both the countries.
# Hence option (b) is the correct answer.

# %% [markdown]
# #### Hybrid Search

# %%
# def hybrid_search(query: str, limit: int = 5, alpha: float = 0.5):
#     """Perform hybrid BM25 + vector search on PYQS questions"""
#     result = (
#         client.query
#         .get("PYQS", ["question", "options", "answer_key", "description"])
#         .with_hybrid(
#             query=query,
#             alpha=alpha,
#             properties=["question", "description"]
#         )
#         .with_limit(limit) 
#         .with_additional(["score", "distance"]) #Vector distance (smaller = closer semantically).
#         .do() #score: Hybrid score (higher = better).
#     )

#     if not result['data']['Get']['PYQS']:
#         return []

#     return [
#         {
#             "question": item["question"],
#             "answer": item["answer_key"],
#             # Handle None values explicitly
#             "bm25_score": float(item["_additional"].get("score", 0.0)) if item["_additional"].get("score") is not None else 0.0,
#             "vector_distance": float(item["_additional"].get("distance", 1.0)) if item["_additional"].get("distance") is not None else 1.0,
#             "hybrid_score": (1 - (float(item["_additional"].get("distance")) if item["_additional"].get("distance") is not None else 1.0)) 
#                             + (float(item["_additional"].get("score")) if item["_additional"].get("score") is not None else 0.0),
#             "explanation": item["description"]
#         }
#         for item in result['data']['Get']['PYQS']
#     ]


# # Example usage
# results = hybrid_search(subtopic3, limit=25 , alpha=0.7)
# print(f"Found {len(results)} relevant questions:\n")

# for idx, result in enumerate(results, 1):
#     print(f"╔{'═'*80}╗")
#     print(f"║ QUESTION {idx}:")
#     print(f"║ {'-'*76}")
#     print(f"║ Q: {result['question']}")
#     print(f"║ {'-'*76}")
#     # print(f"║ BM25 Score:    {result['bm25_score']:.4f}")
#     # print(f"║ Vector Dist:   {result['vector_distance']:.4f}")
#     # print(f"║ Hybrid Score:  {result['hybrid_score']:.4f}")
#     # print(f"║ Correct Answer: {result['answer']}")
    
#     if result['explanation']:
#         print(f"║ {'-'*76}")
#         print(f"║ Explanation: {result['explanation'][:150]}...")  # Truncate long explanations
    
#     print(f"╚{'═'*80}╝\n")

# %%
# key points
# 1. Alpha Tuning: With alpha=0.7, results are weighted 70% toward vector search (semantic matches) and 30% toward BM25 (keywords).
# 2. Weaviate v3 client: doesnt support distance and explain score
# 3. Focus on the hybrid_score for ranking. If you need vector distances, consider migrating to Weaviate v4.
# 4. Trust the Hybrid Score: The hybrid_score (e.g., 0.7000) is the true relevance metric combining BM25 and vector search. Higher = better match.
# 5. Upgrade to Weaviate v4: To access distance, explainScore, and other hybrid search improvements.
# 6. Weaviate v3 Limitation: Hybrid search in v3 does not return distance by default. Your code sets a fallback of 1.0 (the worst possible cosine distance) when distance is missing.
# 7. Action: Remove the distance field from your code if you’re using v3, as it is not meaningful here.
# 8. The output shows all vector_distance values at 1.0, which indicates that Weaviate v3 is not returning the distance field for hybrid search results. This is a known limitation in older Weaviate versions. Here's what you need to do:

# %%
def hybrid_search(query: str, limit: int = 5, alpha: float = 0.5):
    """Perform hybrid BM25 + vector search on MOCKS questions"""
    result = (
        client.query
        .get("MOCKS", ["question", "options", "answer_key", "description"])
        .with_hybrid(
            query=query,
            alpha=alpha,
            properties=["question", "description"]
        )
        .with_limit(limit)
        .with_additional(["score"])  # Only request hybrid `score`
        .do()
    )

    if not result['data']['Get']['MOCKS']:
        return []

    return [
        {
            "question": item["question"],
            "answer": item["answer_key"],
            "hybrid_score": float(item["_additional"].get("score", 0.0)),
            "explanation": item["description"]
        }
        for item in result['data']['Get']['MOCKS']
    ]


# Example usage
results = hybrid_search(subtopic3, limit=50, alpha=0.7)
sorted_results = sorted(results, key=lambda x: x["hybrid_score"], reverse=True)

print(f"\nFound {len(sorted_results)} relevant questions:\n")
for idx, result in enumerate(sorted_results, 1):
    print(f"╔{'═'*80}╗")
    print(f"║ Rank {idx}: Score = {result['hybrid_score']:.4f}")
    print(f"╠{'─'*80}╣")
    print(f"║ Question: {result['question']}")
    if result['explanation']:
        print(f"╠{'─'*80}╣")
        print(f"║ Explanation: {result['explanation'][:150]}...")  # Truncate long text
    print(f"╚{'═'*80}╝\n")
# Out:
# Found 50 relevant questions:
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 1: Score = 0.9571
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: In the context of economy, what does the term Dutch disease refer to?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: • Recently, an observation paper by Economic Advisory Council to the PM (PM-EAC) highlighted the prevalence of Dutch disease in India.
# • Key Observati...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 2: Score = 0.8255
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following statements regarding the Pitts India Act of 1784:
#
# 1. It allowed the Court of Directors of East India Company to manage the political affairs in India.
# 2. The Company's territories in India were for the first time called the 'British possessions in India'.
#
# Which of the statements given above is/are correct?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Pitt's India Act of 1784
#
# In a bid to rectify the defects of the Regulating Act of 1773, the British Parliament passed the
#
# Amending Act of 1781, also...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 3: Score = 0.7616
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following pairs:
# Constitutional Provision Adopted From
# 1. Fundamental Rights : France
# 2. Directive Principles of : Ireland
# State Policy
# 3. Residual Powers with : Canada
# Centre
# 4. Parliamentary Form of : Britain
# Government
# How many of the above pairs are correctly matched?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Government of India Act of 1935:
# Ο Federal Scheme, Office of Governor, Judiciary; Public Service Commissions; Emergency Provisions;
# Administrative Det...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 4: Score = 0.7371
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Which among the following countries are landlocked?
# 1. Uzbekistan
# 2. Iran
# 3. Armenia
# 4. Afghanistan
# 5. Azerbaijan
# Select the correct answer using the code given below.
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: A Landlocked country is an independent sovereign state that does not have direct access to an ocean, such
# as the Atlantic, or to a sea that is not lan...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 5: Score = 0.7096
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following statements regarding the Charter Act of 1833:
# 1. It deprived the legislative powers of the Governors of Bombay and Madras.
# 2. It ended both the commercial and administrative activities of the East India Company.
# 3. It introduced, for the first time, local representation in the Indian (Central) Legislative Council.
# How many of the above statements are correct?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Charter Act of 1833: This Act was the final step towards centralization in British India.
# 0 Features of the Act.
# It made the Governor-General of Benga...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 6: Score = 0.7000
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: According to the Preamble of the Constitution, as adopted by the Constituent Assembly, how many of the following adjectives were used to define the Indian Republic?
#
# 1. Socialist
# 2. Sovereign
# 3. Secular
# 4. Democratic
#
# Select the correct answer using the code given below.
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: The Preamble of the Constitution defines the Indian Republic as Sovereign, Socialist, Secular and Democratic. Of these, Sovereign and Democratic were ...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 7: Score = 0.6602
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Which of the following statements is not correct regarding the Indian Independence Act of 1947?
# (a) It abolished the office of the secretary of state of India and transferred its functions to the Governor general of India.
# (b) It empowered the Constituent Assembly to do ordinary legislations till the new constitution was drafted and enforced.
# (c) It abolished the office of viceroy and provided a governor-general, who was to be appointed by the British King.
# (d) It granted freedom to the Indian princely states either to join the Dominion of India or Dominion of Pakistan or to remain independent.
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Main Features of the Indian Independence Act (1947):
# Ended British rule and declared India independent on August 15, 1947.
# Partitioned India into two ...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 8: Score = 0.6359
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: An Indian citizen may lose his/her citizenship when he/she:
# 1. Acquires the citizenship of any other foreign state during war.
# 2. Unlawfully trades or communicates with the enemy during a war.
# 3. Has been imprisoned in any country for two years after becoming a naturalized citizen within five years.
# Select the correct answer using the code given below.
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: The Citizenship Act (1955) prescribes three ways of losing citizenship whether acquired under the Act or
#  சுவர்prior to it under the Constitution, viz...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 9: Score = 0.5853
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: In the context of trade winds, consider the following statements:
#
# 1. Trade Winds blow from the subtropical high-pressure belts toward the equatorial low-pressure zone.
# 2. Trade Winds blow from the southeast direction in the Northern Hemisphere.
# 3. Trade Winds are stronger over land compared to the oceans.
#
# Which of the statements given above is/are correct?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: • Trade winds can be defined as the wind that flows towards the equator from the north-east in the Northern Hemisphere or from the south-east in the S...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 10: Score = 0.5634
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: In the context of the Indian Polity, the Union Public Service Commission (UPSC) is consulted on which of the following matters?
# 1. While making reservations in favor of a backward class of citizens
# 2. Selection for the chairmanship of tribunals
# 3. All matters relating to methods of recruitment to civil services
# Select the correct answer using the code given below.
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: The Union Public Service Commission (UPSC) is the central recruiting agency in India. Articles 315 to
# 323 in Part XIV of the Constitution contain elab...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 11: Score = 0.5450
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: It separated, for the first time, the legislative and executive functions of the Governor-General's council. In other words, it established a separate Governor-General's legislative council which came to be known as the Indian (Central) Legislative Council. This legislative wing of the council functioned as a mini-parliament, adopting the same procedures as the British Parliament.
# Which of the following Acts has been described by the passage given above?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Charter Act of 1853:
# This was the last of the series of Charter Acts passed by the British Parliament between 1793 and
# 1853. It was a significant cons...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 12: Score = 0.5426
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following countries:
# 1. Jordan
# 2. Morocco
# 3. Tunisia
# 4. Algeria
# Which of the countries given above share a border with the Mediterranean sea?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: The following countries share their borders with the Mediterranean Sea: Spain, France, Monaco, Italy,
# Malta, Slovenia, Croatia, Bosnia and Herzegovina...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 13: Score = 0.5401
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following countries:
#
# 1. Bahrain
# 2. Iran
# 3. Kuwait
# 4. Saudi Arabia
#
# How many of the above countries shared the boundary of the Persian Gulf?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: India and Saudi Arabia:
#
# Context: India and Saudi Arabia signed an agreement on the annual Haj pilgrimage
# Political features:
#
# Located in the Middle E...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 14: Score = 0.5339
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following statements regarding the Government of India Act, 1919:
# 1. It introduced bicameralism in the Central Legislative Council.
# 2. It provided separate electorates for Anglo-Indians and Europeans.
# 3. It created a new office of the High Commissioner for India in London.
# How many of the above statements are correct?
# (a) Only one
# (b) Only two
# (c) All three
# (d) None
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Major Features of the Government of India Act, 1919 (Montagu-Chelmsford Reforms):
# Decentralization and Separation of Powers:
# Relaxed central control o...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 15: Score = 0.5332
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following pairs:
# Passes
# States
# 1. Bom Di La
# : Arunachal Pradesh
# 2. Jelep La
# : Sikkim
# 3. Mana Pass
# : Himachal Pradesh
# 4. Shipki La
# : Uttarakhand
# How many of the pairs given above are correctly matched?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: • A pass is a gap or break in a mountain range or ridge that allows for passage through the area. Passes are
# formed when glaciers or streams erode the...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 16: Score = 0.4659
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following pairs:
# River
# Origin
# Tributary
# 1. Ghaghara
# : Mapchach
# : Rapti
# ungo
# 2. Krishna
# : Trimbekse
# : Musi
# hwar
# 3. Mahanadi
# : Dandakara
# : Barakar
# nya
# How many of the pairs given above are correctly matched?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: • The Ghaghara (also known as the Karnali in Nepal) originates from the Mapchachungo glacier in the
# Tibetan plateau, near Lake Mansarovar. Its importa...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 17: Score = 0.4630
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following:
# 1. Influence of the Government of India Act of 1935
# 2. Single constitution for both Centre and states
# 3. Catering to the needs of a huge population of the country
# How many of the above are reasons for the elephantine size of our Constitution?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: The Constitution of India:
# Ο The Constitution of India is the lengthiest of all the written constitutions of the world. It is a very
# comprehensive, el...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 18: Score = 0.4600
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: The term "Operation Prosperity Guardian" was recently seen in the news. It is aimed at aiding the safe movement of ships in:
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Recent context: The US Secretary of State Lloyd Austin announced a joint maritime security
# initiative called Operation Prosperity Guardian to aid the ...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 19: Score = 0.4450
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following statements regarding the western and eastern coastal plains:
# 1. The short continental shelf on the eastern coast makes it less suitable for the development of ports and harbors.
# 2. Western coastal plains are an example of submerged coastal plains.
# Which of the statements given above is/are correct?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: On the basis of the location and active geomorphological processes, it can be broadly divided into two: (i) the western coastal plains; (ii) the easte...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 20: Score = 0.4308
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: This climate occurs along the west coast of continents in subtropical latitudes between 30° - 40° latitudes e.g. Central California, Central Chile, along the coast in south eastern and south western Australia. These areas come under the influence of sub-tropical high in summer and westerly wind in winter. Hence, the climate is characterised by hot, dry summer and mild, rainy winter.
# Which of the following is best described in the passage given above?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Warm Temperate (Mid-Latitude) Climates-C Warm temperate (mid-latitude) climates extend from 30° -
# 50° of latitude mainly on the eastern and western ma...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 21: Score = 0.4301
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: How many of the following are envisaged as the Right against Exploitation in the Constitution of India?
# 1. Protection against arrest and detention
# 2. Prohibition of employment of children in factories.
# 3. Prohibition of traffic in human beings and forced labour
# Select the correct answer using the code given below.
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Right against Exploitation includes Article 23 and 24 of the Constitution.
# Article 23 prohibits traffic in human beings, begar (forced labour) and oth...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 22: Score = 0.4269
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: This dam is the fourth oldest water-regulator structure in the world and the oldest in India that is still in use. It was built by Karikala king of the Chola Dynasty in 150CE. It was built across the Cauvery River in the Thanjavur district of Tamil Nadu. The above passage describes which of the following dams:
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: • Kallanai Dam (also known as Grand Anicut) is one of the oldest water-regulator structures in the world
# and the oldest in India that is still in use ...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 23: Score = 0.4248
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following events:
# 1. Goa was conferred full statehood
# 2. Creation of the state of Haryana
# 3. Inclusion of the state of Sikkim in the Indian Union
# 4. Formation of the state of Nagaland
# Arrange the above given events in the correct chronological order of their occurrence.
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: India acquired these three territories from the Portuguese by means of a police action in 1961. They were
# constituted as a union territory by the 12th...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 24: Score = 0.4237
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following pairs:
# Ocean relief
# : Description
# 1. Shoals
# : Flat-topped elevation
# with shallow water
# but useful
# for
# navigable purpose
# 2. Guyots
# : Flat-topped
# mountains that do not
# reach
# the
# ocean
# surface
# 3. Trenches
# : Shallow
# depressions
# formed at the
# convergent
# boundaries
# How many of the pairs given above are correctly matched?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: An oceanic basin is the land surface under an ocean that includes the topography under the water. It can be divided into two parts major relief and mi...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 25: Score = 0.3996
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following statements with respect to the India-Gulf Cooperation Council (GCC) relations :
# 1. As of 2020-21, about 30% of India's inward remittances originated from the GCC region.
# 2. GCC countries account for more than 50% of India's oil imports and 70% of its gas imports.
# Which of the statements given above is/are correct?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Share of inward remittances from the GCC region are about 30% (2020-21). Hence, statement 1 is correct.Energy: GCC countries contribute to 35% of Indi...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 26: Score = 0.3881
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: According to the Indian Constitution, which among the following categories of persons would be eligible to become the citizen of India on 26th January 1950?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: According to the Constitution, the following four categories of persons became the citizens of India at its
#
# commencement i.e., on 26 January, 1950:
#
# ...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 27: Score = 0.3878
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Which of the following functions are performed by the National Commission of Scheduled Castes (NCSC)?
# 1. To investigate and monitor all matters relating to the legal safeguards for the SCs
# 2. To provide safeguards against the exploitation of the Anglo-Indian community
# 3. To report to the President on the working of constitutional safeguards provided for SCs
# Select the correct answer using the code given below.
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: The National Commission for Scheduled Castes (SCs) is a constitutional body in the sense that it is
# directly established by Article 338 of the Constit...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 28: Score = 0.3666
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Which of the following happened earliest in the process of state reorganization after independence?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: • S K Dhar Commission: There has been a demand from different regions, particularly South India, for the reorganization of states on a linguistic basi...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 29: Score = 0.3661
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following statements:
# Statement-I: India can acquire a foreign territory or it can cede a part of its territory in favor of a foreign state.
# Statement-II: Sovereign in the Preamble to the Indian Constitution means 'there is no authority above India and is free to conduct its affair'.
# Which one of the following is correct in respect of the above statements?
# (a) Both Statement-I and Statement-II are correct and Statement-II is the correct explanation for Statement-I
# (b) Both Statement-I and Statement-II are correct and Statement-II is not the correct explanation for Statement-I
# (c) Statement-I is correct Statement-II is incorrect
# (d) Statement-I incorrect but Statement-II is correct
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Statement 2 is correct - Sovereign means India is neither a dependency nor a dominion of any other
# state. There is no authority above it and it is fre...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 30: Score = 0.3498
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Which of the following countries are part of the G4 Nations that support each other's bids for permanent seats on the United Nations Security Council?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: G4 Nations
# • The Minister of External Affairs meets foreign ministers of G4 nations in New York. The group reaffirmed its commitment to urgent reform ...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 31: Score = 0.3336
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: In order to ensure the independent and impartial functioning of the Election Commission of India (ECI), which of the following provisions was/were incorporated in the Constitution of India?
#
# 1. The Consitution has debarred the retiring election commissioners from any further appointment by the government.
# 2. The Chief Election Commissioner can be removed in the same manner and on the same grounds as a judge of the Supreme Court.
# 3. The Constitution has specified the term of all the members of ECI.
#
# Select the correct answer using the code given below.
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: • The Election Commission is a permanent and independent body established by the Constitution of India directly to ensure free and fair elections in t...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 32: Score = 0.3271
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following pairs:
# Committees of
# Constituent Assembly
# Chairman
# 1. States Committee
# : Jawaharlal
# Nehru
# 2. Rules of Procedure
# Committee
# : Vallabhbhai
# Patel
# 3. Steering Committee
# : Rajendra
# Prasad
# Which of the pairs given above is/are correctly matched?
# (a) 2 only
# (b) 1 and 2 only
# (c) 1 and 3 only
# (d) 1, 2 and 3
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Major Committees of Constituent Assembly:
# Union Powers Committee - Jawaharlal Nehru
# Union Constitution Committee – Jawaharlal Nehru
# Provincial Constit...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 33: Score = 0.3143
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following statements with respect to Chotanagpur Plateau:
# 1. It is one of the oldest landmasses on the Earth containing Precambrian rocks.
# 2. In the past, it was part of the Deccan plateau.
# 3. Rajmahal hills forms the southernmost boundary of it.
# Which of the statements given above are correct?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: • The Chotanagpur region is a plateau in eastern India, covering the states of Jharkhand, Orissa, West
# Bengal, Bihar, and Chhattisgarh.
# • The Chottana...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 34: Score = 0.3112
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following statements with reference to ocean currents in the Indian Ocean:
# Statement I: Unlike the Atlantic and Pacific Oceans, the ocean currents in the North Indian Ocean change their direction of flow twice a year.
# Statement II: The Northern Indian Ocean is largely landlocked and is influenced by the distinct patterns of monsoonal winds.
# Which one of the following is correct in respect of the above statements?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Oceanic currents are the general movement of a mass of water in a fairly defined direction over a great distance. There are multiple factors that infl...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 35: Score = 0.3087
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following pairs in the context of rainfall distribution in India:
#
# Average Rainfall                          Region
# 1. Heavy Rainfall :         Brahmaputra
# exceeds 400 cm              valley
# 2. Moderate                      :          Northern
# Rainfall between              Ganga plain
# 100-200
# 3. Low Rainfall          :           Western Uttar
# between 50-100 cm                Pradesh
#
# How many pairs given above are correctly matched?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Distribution of Rainfall
# The average annual rainfall in India is about 125 cm, but it has great spatial variations. i.e.
# • Areas of High Rainfall: The...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 36: Score = 0.3016
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: The term 'doldrums' often heard in geography roughly corresponds to which of the following regions?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: The "doldrums" is a popular nautical term that refers to the belt around the Earth near the equator where
# sailing ships sometimes get stuck on windles...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 37: Score = 0.2980
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Which of the following statement best describes “Totalisation Agreement” which was recently seen in the news?
# (a) It is an agreement through which two countries provide greater market access to each other through various measures like lower or zero tariff.
# (b) It is an agreement between two countries that eliminates dual social security deductions between two countries.
# (c) It is an agreement between two countries to prevent Base Erosion And Profit Shifting.
# (d) It ensures elimination of non-tarrif barrier like sanitary and phytosanitary (SPS) measures.
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Recently the 14th Ministerial meeting of the India-US trade policy forum was held in New Delhi.
# India reiterated its longstanding demand for a totalis...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 38: Score = 0.2910
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following statements regarding the expression ‘Union of States' under Article 1:
#
# 1. All the states and union territories are part of the expression ‘Union of States'.
# 2. A Union territory enjoys a similar relationship as states with the Union government.
#
# Which of the statements given above is/are correct?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Article I describes India, that is, Bharat as a 'Union of States rather than a 'Federation of States'.
#
# According to Article 1. the territory of India...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 39: Score = 0.2910
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following statements:
#
# Statement I: The parliamentary system is based on the doctrine of separation of powers between the legislature and executive.
# Statement II: The Indian Parliament is not a sovereign body, unlike the British Parliament.
#
# Which one of the following is correct in respect of the above statements?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Parliamentary system and Presidential system
#
# Modem democratic governments are classified into parliamentary and presidential based on the nature
#
# of ...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 40: Score = 0.2766
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: The power to specify that the people of a foreign territory shall be the citizens of India when a foreign territory becomes part of India is vested in:
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: If any foreign territory becomes a part of India, the Government of India specifies the persons who
#
# among the people of the territory shall be the ci...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 41: Score = 0.2712
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following statements:
# 1. The ocean waters at the equatorial belt records high salinity levels due to higher insolation.
# 2. Formation of Sea Ice in oceans decreases salinity levels.
# Which of the statements given above is/are correct?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Understanding why the sea is salty begins with knowing how water cycles among the ocean's physical
# states: liquid, vapor, and ice.
#
#     As a liquid, w...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 42: Score = 0.2599
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following statements with respect to the rock system of India:
# 1. The Vindhya rock system is largely devoid of metalliferous minerals
# 2. The Dravidian Rock system entirely lies in the peninsular plateau.
# 3. Archean Gneisses and Schist rocks are normally fossiliferous.
# 4. The Bhangar and Khadar regions of the Great Northern Plains contain significant Tertiary rocks.
# Which of the statements given above are correct?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: • India has a complex and diverse geological structure that can be classified into different rock systems
# based on their age, formation, and character...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 43: Score = 0.2578
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: What is common between Bailadila, Kudremukh and Mayurbhanj?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Iron ore mining in India:
# Context: The Competition Commission of India (CCI) publishes a study examining competition in
# the iron ore market.
# Iron ore ...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 44: Score = 0.2571
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following passage :
# It is an intermediate type of climate between the British and the Siberian type of climate. It has features of both the maritime and the continental climates. It has cold, dry winters and warm, wet summers. Winter temperatures may be well blow freezing-point and snow falls to quite a depth. Summers are as warm as the tropics. Though rain falls throughout the year, there is a distinct summer maximum from the easterly winds from the oceans. In the southern hemisphere, this climatic type is absent.
# Which of the climate is being described in the passage given above?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: The Cool Temperate Eastern Margin ( Laurentian) Climate is an intermediate type of climate
# between the British and the Siberian type of climate. It ha...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 45: Score = 0.2513
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: In the context of El Nino, consider the following statements:
#
# 1. El Nino is a climate pattern that causes a warming of sea surface temperatures in the central and eastern Indian Ocean.
# 2. The occurrence of El Nino is associated with reduced rainfall during the Indian monsoon season.
# 3. El Niño typically last nine to twelve months only.
#
# Which of the statements given above is/are correct?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: • El Niño is a climate pattern that describes the unusual warming of surface waters in the eastern tropical Pacific Ocean. El Niño is the "warm phase"...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 46: Score = 0.2462
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Which of the following gives effect to the objective of the Preamble to secure for all its citizen equality, liberty and justice?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: • In India, like most other democracies in the world, rights are mentioned in the Constitution. Some rights which are fundamental to our life are give...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 47: Score = 0.2410
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: The terrigenous deposits are those which are found on the continental shelves and slopes and mainly consist of the rock material derived because of wear and tear.
# With reference to the above paragraph, which of the following are examples of terrigenous deposits?
# 1. Silt
# 2. Clay
# 3. Red clay
# 4. Red mud
# 5. Siliceous oozes
# Select the correct answer using the code given below.
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Terrigenous materials: The continental rocks are disintegrated and decomposed due to various types of
# weathering and thus fine to coarse sediments are...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 48: Score = 0.2347
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following:
# 1. Federal Public Service
# 2. Dyarchy at the center
# 3. Establishment of Reserve Bank of India
# 4. All-India Federation
# How many of the above were provided in the Government of India Act, of 1935?
# (a) Only one
# (b) Only two
# (c) Only three
# (d) All four
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Features of the Government of India Act, 1935:
# All-India Federation:
# The Act proposed the establishment of an All-India Federation consisting of provi...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 49: Score = 0.2325
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Which of the following suitably describes North-east India as per Koppen's classification?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: Koeppen's Classification of Climatic Regions of India : It is an empirical classification based on mean
# annual and mean monthly temperature and precip...
# ╚════════════════════════════════════════════════════════════════════════════════╝
#
# ╔════════════════════════════════════════════════════════════════════════════════╗
# ║ Rank 50: Score = 0.2144
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Question: Consider the following statements regarding the acquisition of citizenship in India:
#
# 1. Currently, a person born outside India automatically becomes an Indian citizen by descent if one of the parents is an Indian citizen.
# 2. A person applying for citizenship by naturalization should have adequate knowledge of any of the languages spoken in India.
#
# Which of the statements given above is/are correct?
# ╠────────────────────────────────────────────────────────────────────────────────╣
# ║ Explanation: December 3, 2004 onwards, a person born outside India shall not be a citizen of India by descent,
#
# unless his birth is registered at an Indian consula...
# ╚════════════════════════════════════════════════════════════════════════════════╝
